# %%
import os
import numpy as np
import pandas as pd
import json
import gensim
import re
import pandas as pd
import gc
import networkx as nx
from scipy.sparse import lil_matrix
from scipy.io import mmwrite, mmread
from collections import defaultdict

aminer_dir = '../data/original'
outputDir = '../data/graph'
word2vec = gensim.models.KeyedVectors.load_word2vec_format('../data/word2vec/GoogleNews-vectors-negative300.bin', binary=True)

# %%
import datetime
date2 = datetime.datetime.now()
print(date2)
# Out:
# 2020-10-15 04:41:58.954619

# %%
#attribute_set = {'title', 'authors', 'venue', 'year', 'n_citation', 'references', 'abstract'}
attribute_set = {'title', 'venue', 'year', 'references'}

paper = {}
for file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:
#for file in ['dblp-ref-3.json']:
    with open(os.path.join(aminer_dir, file)) as f:
        for line in f:
            empty_flag = 0
            data = json.loads(line)
            paper_id = data.pop('id')
            if attribute_set & data.keys() != attribute_set:
                continue
            for attribute in attribute_set:
                if attribute == 'year' or attribute == 'n_citation':
                    continue
                if len(data[attribute]) == 0:
                    empty_flag = 1
            if empty_flag == 0:
                paper[paper_id] = data

len(paper)
# Out:
# 2154706

# %%
venue_list = list(pd.read_table("venue2.csv")['venue'])
venue_list = venue_list[:-4] # OSは除去
print(len(venue_list))
# Out:
# 56
# /Users/shohei/.pyenv/versions/anaconda3-5.3.0/envs/tensorenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
paper = {}
attribute_set = {'title', 'venue', 'year', 'references'}
for file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:
    with open(os.path.join(aminer_dir, file)) as f:
        for line in f:
            empty_flag = 0
            data = json.loads(line)
            paper_id = data.pop('id')
            if attribute_set & data.keys() != attribute_set:
                continue
            if data['year'] >= 2014: # 2014以降は使わない
                continue
            for attribute in attribute_set:
                if attribute == 'year' or attribute == 'n_citation':
                    continue
                if len(data[attribute]) == 0:
                    empty_flag = 1
            if empty_flag == 0:
                if data['venue'] in venue_list:
                    #if data['year'] == 2017:
                    #    data['year'] = 2016
                    paper[paper_id] = data

len(paper)
# Out:
# 99198

# %%
venue_count_dic = {}
for venue in venue_list:
    venue_count_dic[venue] = 0

for paper_id, meta in paper.items():
    venue_count_dic[meta['venue']] += 1

# %%
""""
G = nx.Graph()
year = 2018
paper_id_set = set()

for paper_id, meta in paper.items():
    if year < meta['year']:
        continue
    paper_id_set.add(paper_id)
print("node num : ",len(paper_id_set))

for paper_id in paper_id_set:
    G.add_node(paper_id)
    for reference_id in paper[paper_id]['references']:
        if not reference_id in paper_id_set:
            continue
        G.add_edge(paper_id, reference_id)
print("edge num : ",len(G.edges))
"""
# Out:
# '"\nG = nx.Graph()\nyear = 2018\npaper_id_set = set()\n\nfor paper_id, meta in paper.items():\n    if year < meta[\'year\']:\n        continue\n    paper_id_set.add(paper_id)\nprint("node num : ",len(paper_id_set))\n\nfor paper_id in paper_id_set:\n    G.add_node(paper_id)\n    for reference_id in paper[paper_id][\'references\']:\n        if not reference_id in paper_id_set:\n            continue\n        G.add_edge(paper_id, reference_id)\nprint("edge num : ",len(G.edges))\n'

# %%
"""
connected_component = {}
max_scale = 0
for c in nx.connected_components(G):
    sg = G.subgraph(c)
    if max_scale < len(sg.nodes):
        max_scale = len(sg.nodes)
        max_sg = G.subgraph(c)
    if not len(sg.nodes) in connected_component.keys():
        connected_component[len(sg.nodes)] = 1
    else:
        connected_component[len(sg.nodes)] += 1
connected_component
"""
# Out:
# '\nconnected_component = {}\nmax_scale = 0\nfor c in nx.connected_components(G):\n    sg = G.subgraph(c)\n    if max_scale < len(sg.nodes):\n        max_scale = len(sg.nodes)\n        max_sg = G.subgraph(c)\n    if not len(sg.nodes) in connected_component.keys():\n        connected_component[len(sg.nodes)] = 1\n    else:\n        connected_component[len(sg.nodes)] += 1\nconnected_component\n'

# %%
"""
node_idx_table = {}
for idx, node in enumerate(max_sg.nodes):
    node_idx_table[node] = idx
"""
# Out:
# '\nnode_idx_table = {}\nfor idx, node in enumerate(max_sg.nodes):\n    node_idx_table[node] = idx\n'

# %%
node_idx_table = {}
for idx, node in enumerate(paper.keys()):
    node_idx_table[node] = idx

# %%
rows = []
for node, idx in node_idx_table.items():
    rows.append([node, idx])
df = pd.DataFrame(rows, columns=['node', 'ID'])
df.to_csv(outputDir + '/node_idx.csv', index=False, encoding='utf_8_sig')

# %%
"""
paper = {}
for file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:
#for file in ['dblp-ref-3.json']:
    with open(os.path.join(aminer_dir, file)) as f:
        for line in f:
            empty_flag = 0
            data = json.loads(line)
            paper_id = data.pop('id')
            if not paper_id in node_idx_table:
                continue
            if attribute_set & data.keys() != attribute_set:
                continue
            for attribute in attribute_set:
                if attribute == 'year' or attribute == 'n_citation':
                    continue
                if len(data[attribute]) == 0:
                    empty_flag = 1
            if empty_flag == 0:
                paper[paper_id] = data

len(paper)
"""
# Out:
# "\npaper = {}\nfor file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:\n#for file in ['dblp-ref-3.json']:\n    with open(os.path.join(aminer_dir, file)) as f:\n        for line in f:\n            empty_flag = 0\n            data = json.loads(line)\n            paper_id = data.pop('id')\n            if not paper_id in node_idx_table:\n                continue\n            if attribute_set & data.keys() != attribute_set:\n                continue\n            for attribute in attribute_set:\n                if attribute == 'year' or attribute == 'n_citation':\n                    continue\n                if len(data[attribute]) == 0:\n                    empty_flag = 1\n            if empty_flag == 0:\n                paper[paper_id] = data\n\nlen(paper)\n"

# %%
#venue_set = set()
#for paper_id, meta in paper.items():
#    venue_set.add(meta['venue'])

# %%
#df = pd.DataFrame({'venue': list(venue_set)})
#df.to_csv("venue.csv")

# %%
years = set()
for paper_id, meta in paper.items():
    years.add(paper[paper_id]['year'])
years = list(years)
years.sort()
years
# Out:
# [1965,
#  1967,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
#field_list = ["WEB", "ML", "DM", "IR", "DB", "HI", "NLP", "CV", "COM", "OS"]
field_list = ["WEB", "ML", "DM", "IR", "DB", "HI", "NLP", "CV", "COM"]
field_venue_dic = defaultdict(list)

for idx, venue in enumerate(venue_list):
    if idx < 5:
        field_venue_dic["WEB"].append(venue)
    elif idx < 12:
        field_venue_dic["ML"].append(venue)
    elif idx < 19:
        field_venue_dic["DM"].append(venue)
    elif idx < 25:
        field_venue_dic["IR"].append(venue)
    elif idx < 34:
        field_venue_dic["DB"].append(venue)
    elif idx < 42:
        field_venue_dic["HI"].append(venue)
    elif idx < 47:
        field_venue_dic["NLP"].append(venue)
    elif idx < 51:
        field_venue_dic["CV"].append(venue)
    elif idx < 56:
        field_venue_dic["COM"].append(venue)
    #else:
    #    field_venue_dic["OS"].append(venue)

field_venue_dic
# Out:
# defaultdict(list,
#             {'WEB': ['World Wide Web',
#               'international world wide web conferences',
#               'international semantic web conference',
#               'Journal of Web Semantics',
#               'european semantic web conference'],
#              'ML': ['Artificial Intelligence',
#               'international joint conference on artificial intelligence',
#               'international conference on neural information processing',
#               'neural information processing systems',
#               'international conference on machine learning',
#               'Machine Learning',
#               'international conference on learning representations'],
#              'DM': ['Sigkdd Explorations',
#               'Data Mining and Knowledge Discovery',
#               'workshop on knowledge discovery and data mining',
#               'knowledge discovery and data mining',
#               'international conference on data mining',
#               'siam international conference on data mining',
#               'web search and data mining'],
#              'IR': ['Sigir Forum',
#               'international acm sigir conference on research and development in information retrieval',
#               'Information Retrieval',
#               'conference on information and knowledge management',
#               'Journal of Information & Knowledge Management',
#               'conference on recommender systems'],
#              'DB': ['Sigmod Record',
#               'international conference on management of data',
#               'conference on management of data',
#               'symposium on principles of database systems',
#               'Proceedings of The Vldb Endowment',
#               'The Vldb Journal',
#               'very large data bases',
#               'international conference on data engineering',
#               'extending database technology'],
#              'HI': ['ACM Sigchi Bulletin',
#               'human factors in computing systems',
#               'Human Factors',
#               'intelligent user interfaces',
#               'european conference on computer supported cooperative work',
#               'Computer Supported Cooperative Work',
#               'conference on computer supported cooperative work',
#               'user interface software and technology'],
#              'NLP': ['Computational Linguistics',
#               'meeting of the association for computational linguistics',
#               'empirical methods in natural language processing',
#               'international conference on computational linguistics',
#               'north american chapter of the association for computational linguistics'],
#              'CV': ['computer vision and pattern recognition',
#               'international conference on computer vision',
#               'International Journal of Computer Vision',
#               'european conference on computer vision'],
#              'COM': ['acm special interest group on data communication',
#               'Computer Communications',
#               'international conference on computer communications',
#               'acm/ieee international conference on mobile computing and networking',
#               'acm ieee international conference on mobile computing and networking']})

# %%
field_count_dic = {}
for field in field_list:
    field_count_dic[field] = 0

for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    field_count_dic[field] += 1

field_count_dic
# Out:
# {'WEB': 5177,
#  'ML': 17015,
#  'DM': 8426,
#  'IR': 7496,
#  'DB': 12015,
#  'HI': 12383,
#  'NLP': 10181,
#  'CV': 14696,
#  'COM': 11809}

# %%
year_field_count = np.zeros((len(years), len(field_list)))
for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    year_field_count[years.index(meta['year'])][field_list.index(field)] +=1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

for f_idx in range(len(field_list)):
    plt.plot(years, year_field_count[:, f_idx], label=field_list[f_idx])
plt.xlabel("year")
plt.ylabel("the # of papers")
plt.legend()
plt.savefig("num_of_paper_field.pdf")

# %%
plt.figure()
plt.plot(years, year_field_count.sum(axis=1))
plt.xlabel("year")
plt.ylabel("the # of papers")
plt.savefig("num_of_paper.pdf")

# %%
node_attribute = np.zeros((len(node_idx_table), 300))
for paper_id, meta in paper.items():
    vector = np.zeros((300))
    #print(meta['title'])
    n_word = 0
    for word in meta['title'].split(' '):
        try:
            vector = vector + word2vec[word]
            n_word += 1
            #print(word)
        except KeyError as error:
            pass
            #print(error)
    if n_word == 0:
        node_attribute[node_idx_table[paper_id]] = vector
    else:
        node_attribute[node_idx_table[paper_id]] = vector / n_word
    #print(node_attribute[node_idx_table[paper_id]])
    #print(" ")

# %%
# 低次元に写像しクラスタを可視化
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
node_attribute_pca = pca.fit_transform(node_attribute)
print(node_attribute_pca.shape)
# Out:
# (99198, 2)

# %%
n_clusters = len(field_list)
x_field = [[] for _ in range(n_clusters)]
y_field = [[] for _ in range(n_clusters)]
for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    i = field_list.index(field)
    x_field[i].append(node_attribute_pca[node_idx_table[paper_id]][0])
    y_field[i].append(node_attribute_pca[node_idx_table[paper_id]][1])

# %%
import matplotlib.colors as mcolors
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
colors = [val for key, val in mcolors.TABLEAU_COLORS.items()]

for i in range(n_clusters):
    ax.scatter(x_field[i], y_field[i], c=colors[i], label=field_list[i])

ax.legend()
fig.savefig('scatter_word2vec.pdf')

# %%
# 分野ごとの論文を抽出して連結し文書化する。

def Isalnum(s):
    alnumReg = re.compile(r'^[a-zA-Z0-9]+$')
    return alnumReg.match(s) is not None

n_clusters = len(field_list)

cluster_title_list = [[] for _ in range(n_clusters)]
for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    cluster_title_list[field_list.index(field)].append(meta['title'])

documents = []
for title_list in cluster_title_list:
    title_list = ' '.join(title_list)
    title_list = str.lower(title_list)
    notalnum = set()
    for s in set(title_list):
        if s != ' ' and not Isalnum(s):
            notalnum.add(s)
            #print(s) # 記号（文字や数値でないもの）
    for s in notalnum:
        title_list = title_list.replace(s, ' ')
    documents.append(title_list)

# %%
# TF-IDFを計算し、各クラスタごとの代表的な単語を上位数件表示する。

from gensim import corpora
from gensim import models

# gensim用に整形
texts = list(map(lambda x:x.split(),documents))

# 単語->id変換の辞書作成
dictionary = corpora.Dictionary(texts)
#print(dictionary.token2id)

# textsをcorpus化
corpus = list(map(dictionary.doc2bow,texts))
#print(corpus)

# tfidf modelの生成
test_model = models.TfidfModel(corpus)

# corpusへのモデル適用
corpus_tfidf = test_model[corpus]

texts_tfidf = []
for doc in corpus_tfidf:
    text_tfidf = []
    for word in doc:
        text_tfidf.append((dictionary[word[0]],word[1]))
    texts_tfidf.append(text_tfidf)

keyword_tfidf_cluster_list = []
for idx, text in enumerate(texts_tfidf):
    print(field_list[idx])
    keyword_tfidf_cluster_list.append({})
    for keyword in sorted(text, key=lambda x:(x[1]), reverse=True)[:150]:
        print('   %.3f %s' %(keyword[1], keyword[0]))
        keyword_tfidf_cluster_list[idx][keyword[0]] = keyword[1]
# Out:
# WEB
#    0.503 rdf
#    0.382 owl
#    0.347 sparql
#    0.165 xml
#    0.118 service
#    0.102 restful
#    0.094 ontologies
#    0.091 rdfs
#    0.082 skos
#    0.079 caching
#    0.076 dl
#    0.066 daml
#    0.064 dbpedia
#    0.063 xslt
#    0.055 publishing
#    0.053 dc
#    0.053 matchmaking
#    0.051 bioportal
#    0.051 oaei
#    0.051 reasoner
#    0.051 smil
#    0.051 webml
#    0.051 provenance
#    0.049 wikipedia
#    0.049 crawling
#    0.046 lifecycle
#    0.045 folksonomy
#    0.044 http
#    0.041 pagerank
#    0.041 irs
#    0.041 mashups
#    0.041 matchmaker
#    0.041 metamodeling
#    0.041 sawsdl
#    0.041 wsmo
#    0.040 enterprise
#    0.039 p2p
#    0.038 folksonomies
#    0.038 html
#    0.036 hypermedia
#    0.036 entailment
#    0.036 lod
#    0.036 ws
#    0.036 xquery
#    0.035 advertiser
#    0.035 pdas
#    0.035 rl
#    0.034 annotation
#    0.034 authoring
#    0.034 mashup
#    0.034 triples
#    0.032 answering
#    0.031 bpel4ws
#    0.031 browsers
#    0.031 choreography
#    0.031 datatypes
#    0.031 dbin
#    0.031 earthquake
#    0.031 gnowsis
#    0.031 isparql
#    0.031 mediawiki
#    0.031 observatories
#    0.031 odesew
#    0.031 ourspaces
#    0.031 potluck
#    0.031 r2rml
#    0.031 rdfa
#    0.031 sambo
#    0.031 sameas
#    0.031 scientometrics
#    0.031 shop2
#    0.031 sitemaps
#    0.031 wsmx
#    0.031 xpath
#    0.030 wikis
#    0.030 heritage
#    0.029 metadata
#    0.028 twitter
#    0.028 recommender
#    0.028 oxpath
#    0.028 paid
#    0.028 ql
#    0.028 reasoners
#    0.028 entity
#    0.027 crawler
#    0.027 federated
#    0.027 interoperability
#    0.026 javascript
#    0.026 middleware
#    0.026 ajax
#    0.026 bpel
#    0.026 com
#    0.026 dns
#    0.026 freshness
#    0.025 compositions
#    0.025 mediation
#    0.024 communities
#    0.023 delivery
#    0.023 apis
#    0.023 bookmarking
#    0.023 mash
#    0.023 suggestions
#    0.022 lite
#    0.022 museum
#    0.021 desktop
#    0.021 opinion
#    0.021 ants
#    0.021 blank
#    0.021 demonstrator
#    0.021 fake
#    0.021 gov
#    0.021 homepage
#    0.021 ics
#    0.021 interlinking
#    0.021 magpie
#    0.021 prov
#    0.021 swrl
#    0.021 syndication
#    0.021 webdav
#    0.021 markup
#    0.021 rewriting
#    0.020 abox
#    0.020 activerdf
#    0.020 agree
#    0.020 allright
#    0.020 apfel
#    0.020 beagle
#    0.020 bottari
#    0.020 bpm
#    0.020 chatty
#    0.020 cream
#    0.020 cwb
#    0.020 dbrec
#    0.020 dhts
#    0.020 directorate
#    0.020 dispatcher
#    0.020 disputed
#    0.020 dolce
#    0.020 domotic
#    0.020 dsnotify
#    0.020 dysplasia
#    0.020 ecoinformatics
#    0.020 edutella
#    0.020 empowered
#    0.020 endpoints
#    0.020 eswc
#    0.020 evolva
#    0.020 evolvement
#    0.020 factpages
#    0.020 foaf
# ML
#    0.289 spiking
#    0.235 neurons
#    0.190 mdps
#    0.144 plasticity
#    0.133 gaussian
#    0.118 nonmonotonic
#    0.116 backpropagation
#    0.111 neuron
#    0.101 gradient
#    0.094 spike
#    0.091 cortex
#    0.090 recurrent
#    0.089 cortical
#    0.083 regularized
#    0.081 logics
#    0.081 reinforcement
#    0.081 circumscription
#    0.081 pomdps
#    0.079 firing
#    0.079 kernel
#    0.078 variational
#    0.076 synaptic
#    0.074 autoepistemic
#    0.074 csps
#    0.074 sparse
#    0.074 motor
#    0.074 proving
#    0.072 boltzmann
#    0.070 csp
#    0.070 bci
#    0.069 kernels
#    0.066 multiagent
#    0.065 covariance
#    0.064 silicon
#    0.063 minimax
#    0.063 bounds
#    0.062 bandit
#    0.058 factored
#    0.057 hebbian
#    0.057 abduction
#    0.057 manifold
#    0.056 regularization
#    0.056 mlp
#    0.056 stdp
#    0.056 eeg
#    0.055 fmri
#    0.054 chess
#    0.054 equilibria
#    0.054 equilibrium
#    0.053 sparsity
#    0.053 bandits
#    0.052 stochastic
#    0.052 dirichlet
#    0.052 convex
#    0.051 lasso
#    0.051 apprenticeship
#    0.051 rbf
#    0.051 existential
#    0.051 hippocampal
#    0.051 perceptrons
#    0.051 analog
#    0.050 saliency
#    0.050 priors
#    0.049 ai
#    0.049 receptive
#    0.048 speaker
#    0.048 chaotic
#    0.047 default
#    0.046 allen
#    0.046 coalitional
#    0.046 epistemic
#    0.046 sensorimotor
#    0.046 synapses
#    0.046 planner
#    0.046 vlsi
#    0.046 pac
#    0.045 nonparametric
#    0.045 satisfiability
#    0.044 critic
#    0.044 margins
#    0.044 defeasible
#    0.044 natural
#    0.043 neuronal
#    0.043 ica
#    0.043 roc
#    0.043 texture
#    0.043 robot
#    0.042 theories
#    0.042 nonnegative
#    0.042 backgammon
#    0.042 quantified
#    0.041 td
#    0.041 prolog
#    0.041 discriminant
#    0.040 reward
#    0.040 decoding
#    0.039 armed
#    0.039 learnability
#    0.039 denoising
#    0.038 factorization
#    0.038 connectionist
#    0.038 plans
#    0.038 nash
#    0.038 ocular
#    0.038 rewards
#    0.038 deduction
#    0.038 descent
#    0.038 meetings
#    0.037 bayes
#    0.037 particle
#    0.037 forgetting
#    0.037 semidefinite
#    0.037 stimulus
#    0.037 topographic
#    0.036 arc
#    0.036 auditory
#    0.036 emergence
#    0.036 neuro
#    0.036 possibilistic
#    0.035 sat
#    0.035 neuromorphic
#    0.035 entailment
#    0.035 admissible
#    0.035 imitation
#    0.035 circuits
#    0.034 manifolds
#    0.034 nets
#    0.034 pairwise
#    0.034 horn
#    0.034 logistic
#    0.034 stereo
#    0.033 finite
#    0.033 abductive
#    0.033 robotics
#    0.032 dec
#    0.032 neocognitron
#    0.032 oscillator
#    0.032 resting
#    0.032 ebl
#    0.032 inhibition
#    0.032 overcomplete
#    0.031 qualitative
#    0.031 beliefs
#    0.031 pursuit
#    0.031 perceptron
#    0.031 backtracking
#    0.031 convolutional
#    0.031 laplacian
#    0.031 observable
#    0.031 pulse
# DM
#    0.385 cup
#    0.338 itemsets
#    0.312 kdd
#    0.100 microarray
#    0.099 climate
#    0.098 factorization
#    0.089 nonnegative
#    0.085 privacy
#    0.084 episodes
#    0.068 biclustering
#    0.067 cancer
#    0.067 regularized
#    0.065 discovered
#    0.064 customers
#    0.062 granger
#    0.062 pathways
#    0.062 peculiarity
#    0.061 marketing
#    0.061 olap
#    0.061 motifs
#    0.058 discretization
#    0.058 itemset
#    0.058 outliers
#    0.057 kernel
#    0.056 dirichlet
#    0.054 miner
#    0.054 pairwise
#    0.052 imbalanced
#    0.052 kernels
#    0.052 recommender
#    0.052 clickstream
#    0.052 outbreak
#    0.052 squashing
#    0.052 discriminant
#    0.051 sentiment
#    0.050 logistic
#    0.050 nearest
#    0.050 imbalance
#    0.049 sparse
#    0.048 interestingness
#    0.048 bayes
#    0.047 gene
#    0.047 subsequences
#    0.046 interesting
#    0.046 categorical
#    0.046 clusterings
#    0.046 differentially
#    0.046 subgroup
#    0.045 subspace
#    0.044 dimensionality
#    0.043 ensembles
#    0.043 yeast
#    0.043 episode
#    0.043 metabolic
#    0.042 churn
#    0.042 agglomerative
#    0.042 roc
#    0.042 drifting
#    0.042 arbitrarily
#    0.042 biomarker
#    0.042 blanket
#    0.042 sell
#    0.042 webkdd
#    0.040 rough
#    0.039 outlier
#    0.038 manifold
#    0.038 protein
#    0.036 publishing
#    0.036 imputation
#    0.036 lung
#    0.036 proteins
#    0.036 projected
#    0.036 mml
#    0.035 basket
#    0.035 anomalous
#    0.035 covariance
#    0.035 anonymization
#    0.034 opinion
#    0.034 tensor
#    0.033 interpretable
#    0.033 motif
#    0.033 sparsity
#    0.033 transactional
#    0.033 customer
#    0.032 subgraph
#    0.031 bicluster
#    0.031 boilers
#    0.031 cfb
#    0.031 cprod1
#    0.031 derivable
#    0.031 drought
#    0.031 geoscientific
#    0.031 hyperclique
#    0.031 intelligible
#    0.031 lu
#    0.031 miners
#    0.031 precursors
#    0.031 professor
#    0.031 securities
#    0.031 shapelets
#    0.031 underrepresented
#    0.031 regularization
#    0.031 sales
#    0.031 colony
#    0.031 committee
#    0.031 genes
#    0.031 lasso
#    0.031 substructures
#    0.031 warping
#    0.031 influential
#    0.031 bagging
#    0.031 ordinal
#    0.031 cube
#    0.029 gaussian
#    0.028 competitors
#    0.028 lift
#    0.028 spacecraft
#    0.028 commute
#    0.028 rna
#    0.028 sax
#    0.028 weka
#    0.028 categorization
#    0.028 entity
#    0.028 viral
#    0.027 fraud
#    0.027 sensing
#    0.027 significance
#    0.026 named
#    0.026 svms
#    0.026 unlabeled
#    0.026 hyperplane
#    0.026 nmf
#    0.026 orange
#    0.026 exceptional
#    0.026 subtrees
#    0.026 massive
#    0.025 sensor
#    0.025 bioinformatics
#    0.025 publication
#    0.025 patent
#    0.025 unexpected
#    0.025 actionable
#    0.025 bias
#    0.025 subgraphs
#    0.025 randomization
#    0.025 gradient
#    0.024 xml
#    0.023 bid
#    0.023 television
#    0.023 bregman
# IR
#    0.227 sigir
#    0.227 recommender
#    0.192 xml
#    0.177 ntcir
#    0.164 passage
#    0.154 trec
#    0.139 assessor
#    0.095 inex
#    0.095 stemming
#    0.091 diversification
#    0.088 esair
#    0.084 enterprise
#    0.084 wikipedia
#    0.082 metasearch
#    0.081 federated
#    0.078 km
#    0.078 patent
#    0.076 bm25
#    0.076 ecir
#    0.075 recommending
#    0.074 factorization
#    0.071 question
#    0.069 sentiment
#    0.065 judgments
#    0.063 organisational
#    0.063 searcher
#    0.063 eine
#    0.063 tipster
#    0.062 opinion
#    0.062 answering
#    0.061 rdf
#    0.061 olap
#    0.060 entity
#    0.058 articles
#    0.058 recommendations
#    0.057 files
#    0.057 organisations
#    0.057 acm
#    0.057 monolingual
#    0.056 recommenders
#    0.053 categorization
#    0.052 multilingual
#    0.052 subtopic
#    0.051 caching
#    0.051 pagerank
#    0.051 thesaurus
#    0.051 personalize
#    0.051 xpath
#    0.051 booksonline
#    0.051 controversial
#    0.051 ein
#    0.051 recsys
#    0.051 tdt
#    0.051 verbose
#    0.048 sentence
#    0.047 collections
#    0.047 effectiveness
#    0.047 distillation
#    0.047 suggestions
#    0.045 blog
#    0.045 indexes
#    0.044 duplicate
#    0.044 hyperlink
#    0.044 twig
#    0.044 clir
#    0.044 transliteration
#    0.044 companies
#    0.043 corpus
#    0.043 inverted
#    0.043 named
#    0.043 contextualization
#    0.043 stemmer
#    0.042 bibliographic
#    0.042 keyphrase
#    0.041 clickthrough
#    0.040 crawling
#    0.040 poster
#    0.038 factoid
#    0.038 intellectual
#    0.038 multidatabase
#    0.038 plagiarism
#    0.038 plsa
#    0.038 warehousing
#    0.038 aboutness
#    0.038 barriers
#    0.038 cite
#    0.038 ineffectiveness
#    0.038 jordanian
#    0.038 malaysia
#    0.038 malaysian
#    0.038 rocchio
#    0.038 simfusion
#    0.038 smes
#    0.038 symposium
#    0.038 und
#    0.038 zur
#    0.037 dbms
#    0.037 reranking
#    0.037 regularized
#    0.037 european
#    0.036 corpora
#    0.036 annotation
#    0.035 suggestion
#    0.035 searchers
#    0.035 retweet
#    0.035 subtopics
#    0.035 categorisation
#    0.035 dolap
#    0.035 mentions
#    0.035 oodb
#    0.035 phrasal
#    0.035 retrieve
#    0.035 tokenization
#    0.034 fact
#    0.034 joins
#    0.034 skyline
#    0.033 nearest
#    0.033 capital
#    0.033 difficult
#    0.033 difficulty
#    0.033 dirichlet
#    0.033 folksonomy
#    0.033 indices
#    0.033 spammers
#    0.033 pairwise
#    0.033 affecting
#    0.033 idf
#    0.032 english
#    0.032 interests
#    0.032 freshness
#    0.032 ria
#    0.032 versioned
#    0.032 definitional
#    0.032 posting
#    0.032 tacit
#    0.032 disks
#    0.032 tf
#    0.030 bilingual
#    0.030 personalised
#    0.030 posts
#    0.030 reachability
#    0.030 pooling
#    0.030 rfid
#    0.030 file
#    0.030 reviews
#    0.030 cold
#    0.030 sql
#    0.029 engines
#    0.029 topics
#    0.029 japanese
# DB
#    0.377 xml
#    0.235 dbms
#    0.215 xquery
#    0.212 xpath
#    0.207 joins
#    0.181 sql
#    0.171 olap
#    0.164 db2
#    0.128 oltp
#    0.127 skyline
#    0.123 warehousing
#    0.115 materialized
#    0.114 concurrency
#    0.100 lineage
#    0.082 locking
#    0.081 multidatabase
#    0.079 warehouse
#    0.078 transaction
#    0.078 declustering
#    0.078 serializability
#    0.076 rdf
#    0.075 oracle
#    0.073 join
#    0.069 provenance
#    0.068 privacy
#    0.068 schema
#    0.067 synopses
#    0.066 caching
#    0.064 rdbms
#    0.062 nearest
#    0.061 sparql
#    0.061 twig
#    0.061 optimizer
#    0.057 cube
#    0.055 replication
#    0.054 semistructured
#    0.054 transitive
#    0.053 dbmss
#    0.053 skylines
#    0.053 reorganization
#    0.053 multiversion
#    0.052 files
#    0.050 moving
#    0.050 aqualogic
#    0.050 sigmod
#    0.050 oodb
#    0.049 transactions
#    0.048 buffer
#    0.048 workloads
#    0.047 disks
#    0.047 nothing
#    0.047 replicated
#    0.047 hadoop
#    0.047 mapreduce
#    0.046 optimizers
#    0.046 tuples
#    0.045 commit
#    0.045 tertiary
#    0.043 logging
#    0.043 deductive
#    0.042 b
#    0.042 tpc
#    0.042 rfid
#    0.041 auditing
#    0.041 multiprocessor
#    0.041 file
#    0.040 rewriting
#    0.040 main
#    0.039 datalog
#    0.039 warehouses
#    0.039 advisor
#    0.039 codasyl
#    0.039 snapshot
#    0.038 schemas
#    0.038 dataspaces
#    0.037 federated
#    0.037 enterprise
#    0.036 etl
#    0.036 resident
#    0.036 transactional
#    0.036 outsourced
#    0.035 indexes
#    0.035 p2p
#    0.035 publishing
#    0.035 itemsets
#    0.035 encrypted
#    0.034 reachability
#    0.034 containment
#    0.034 selectivity
#    0.033 buffering
#    0.033 clio
#    0.033 extendible
#    0.033 hana
#    0.033 hippocratic
#    0.033 ldap
#    0.033 locks
#    0.033 monetdb
#    0.033 nonrecursive
#    0.033 pig
#    0.033 postgresql
#    0.033 serializable
#    0.033 service
#    0.033 predicates
#    0.033 microsoft
#    0.033 subscribe
#    0.032 flash
#    0.032 integrity
#    0.031 imprecise
#    0.031 sensor
#    0.031 differentially
#    0.031 quantiles
#    0.031 sap
#    0.031 cpus
#    0.031 aries
#    0.031 starburst
#    0.029 answering
#    0.029 versioning
#    0.029 answers
#    0.028 conscious
#    0.028 freshness
#    0.028 tenant
#    0.028 11g
#    0.028 exodus
#    0.028 nail
#    0.028 oracle8i
#    0.028 ssds
#    0.028 vldb
#    0.027 aggregates
#    0.027 protocols
#    0.027 workflows
#    0.027 db
#    0.027 middleware
#    0.027 parallelism
#    0.027 atomicity
#    0.027 executions
#    0.027 postgres
#    0.027 subqueries
#    0.027 hitters
#    0.027 quorum
#    0.026 predicate
#    0.025 bulk
#    0.025 cad
#    0.025 managing
#    0.025 cpu
#    0.025 duplicates
#    0.025 lock
#    0.025 scans
#    0.025 trie
#    0.025 neighbor
#    0.024 pipelined
# HI
#    0.257 hci
#    0.249 tabletop
#    0.246 tangible
#    0.171 cscw
#    0.164 pointing
#    0.154 tactile
#    0.120 handed
#    0.118 para
#    0.115 screen
#    0.115 keyboard
#    0.109 intera
#    0.108 groupware
#    0.099 tabletops
#    0.094 da
#    0.091 um
#    0.089 avalia
#    0.089 usu
#    0.086 menus
#    0.085 uma
#    0.082 es
#    0.079 pen
#    0.075 estudo
#    0.071 everyday
#    0.070 gestures
#    0.069 adults
#    0.068 finger
#    0.068 usabilidade
#    0.066 haptic
#    0.065 gaze
#    0.061 designers
#    0.061 goms
#    0.061 keyboards
#    0.061 rios
#    0.060 mediated
#    0.058 fitts
#    0.058 sistemas
#    0.058 practices
#    0.057 auditory
#    0.057 older
#    0.056 widgets
#    0.056 entertainment
#    0.056 engaging
#    0.056 touchscreen
#    0.056 participatory
#    0.055 pressure
#    0.055 storytelling
#    0.055 homeless
#    0.055 ui
#    0.054 children
#    0.053 drawing
#    0.051 sig
#    0.051 interruption
#    0.051 aplica
#    0.050 messaging
#    0.049 projector
#    0.049 touch
#    0.048 appropriation
#    0.048 qwerty
#    0.048 sobre
#    0.048 creative
#    0.048 wearable
#    0.047 programmers
#    0.047 multitasking
#    0.047 workplace
#    0.046 handheld
#    0.045 meetings
#    0.044 immersion
#    0.044 stylus
#    0.044 menu
#    0.044 workspace
#    0.044 usability
#    0.043 gaming
#    0.043 com
#    0.042 sickness
#    0.042 cursor
#    0.041 posture
#    0.041 caso
#    0.041 involvement
#    0.041 leisure
#    0.041 love
#    0.041 tica
#    0.041 uso
#    0.041 ux
#    0.041 veis
#    0.040 distraction
#    0.039 ethnography
#    0.039 autism
#    0.039 teams
#    0.039 embodied
#    0.038 visualizations
#    0.038 gesture
#    0.038 cues
#    0.038 gestural
#    0.038 domestic
#    0.038 workspaces
#    0.038 encourage
#    0.038 lise
#    0.038 scaffolding
#    0.037 novice
#    0.037 inform
#    0.037 warnings
#    0.037 sensemaking
#    0.036 experience
#    0.036 mounted
#    0.035 emotional
#    0.035 interpersonal
#    0.035 multitouch
#    0.035 walkthrough
#    0.035 affordances
#    0.035 brainstorming
#    0.035 awareness
#    0.034 conferencing
#    0.034 bimanual
#    0.034 gameplay
#    0.034 guis
#    0.034 ihc
#    0.034 vibrotactile
#    0.034 screens
#    0.034 perceptions
#    0.034 sustainability
#    0.034 creativity
#    0.034 o
#    0.033 personas
#    0.032 informing
#    0.032 impaired
#    0.032 persuasive
#    0.032 reflection
#    0.032 surfaces
#    0.031 facebook
#    0.031 3d
#    0.031 desafios
#    0.031 feeling
#    0.031 friction
#    0.031 interruptibility
#    0.031 proposta
#    0.031 revisitation
#    0.031 sistema
#    0.031 sociotechnical
#    0.031 toys
#    0.031 uis
#    0.031 women
#    0.030 dos
#    0.030 healthy
#    0.030 animated
#    0.030 physical
#    0.029 play
#    0.029 interventions
#    0.029 teamwork
#    0.029 ambient
#    0.029 stroke
# NLP
#    0.228 smt
#    0.216 parser
#    0.216 treebank
#    0.210 dialogue
#    0.189 adjoining
#    0.170 verb
#    0.162 bilingual
#    0.158 morphological
#    0.148 lexical
#    0.139 ccg
#    0.137 entailment
#    0.125 noun
#    0.124 coreference
#    0.123 selectional
#    0.118 pos
#    0.114 transliteration
#    0.111 categorial
#    0.107 corpus
#    0.100 semeval
#    0.098 parse
#    0.097 english
#    0.095 monolingual
#    0.094 mt
#    0.093 discourse
#    0.090 chunking
#    0.090 hpsg
#    0.087 paraphrases
#    0.087 wsd
#    0.085 lfg
#    0.084 sentence
#    0.082 corpora
#    0.081 paraphrase
#    0.081 ellipsis
#    0.081 morphologically
#    0.079 phrasal
#    0.079 french
#    0.076 sentiment
#    0.075 anaphora
#    0.075 parsers
#    0.071 spoken
#    0.069 penn
#    0.069 preposition
#    0.069 decoding
#    0.068 named
#    0.068 japanese
#    0.065 morphology
#    0.064 lexicalized
#    0.061 german
#    0.061 distributional
#    0.060 multilingual
#    0.060 korean
#    0.060 paraphrasing
#    0.060 tagger
#    0.058 natural
#    0.058 pcfg
#    0.056 pronoun
#    0.055 chinese
#    0.055 lexicon
#    0.054 constituent
#    0.054 acl2
#    0.054 pronominal
#    0.054 pronouns
#    0.054 underspecified
#    0.054 syntactic
#    0.053 combinatory
#    0.053 sentential
#    0.052 grammars
#    0.052 centering
#    0.051 nlp
#    0.051 grammatical
#    0.050 esl
#    0.050 hebrew
#    0.050 treebanks
#    0.050 wmt
#    0.049 phrase
#    0.048 referring
#    0.048 extractive
#    0.046 multiword
#    0.046 morpheme
#    0.046 polysemy
#    0.045 formalisms
#    0.045 taggers
#    0.045 subcategorization
#    0.045 finite
#    0.044 transducers
#    0.042 linguistically
#    0.042 hardbound
#    0.042 lambek
#    0.042 arabic
#    0.041 spanish
#    0.041 entity
#    0.041 reordering
#    0.041 nouns
#    0.040 linguistic
#    0.040 urdu
#    0.039 phoneme
#    0.039 pronunciation
#    0.039 literary
#    0.039 metonymy
#    0.038 comparable
#    0.037 dialogues
#    0.037 morpho
#    0.037 compounds
#    0.037 tense
#    0.036 reranking
#    0.036 verbs
#    0.036 tagging
#    0.036 prosodic
#    0.035 framenet
#    0.035 bengali
#    0.035 decipherment
#    0.035 determiner
#    0.035 unlexicalized
#    0.034 portuguese
#    0.034 hindi
#    0.034 dictionaries
#    0.033 wordnet
#    0.033 subjectivity
#    0.033 czech
#    0.033 phonological
#    0.033 rhetorical
#    0.033 turkish
#    0.033 isbn
#    0.032 question
#    0.032 chart
#    0.032 languages
#    0.032 phonology
#    0.032 prepositional
#    0.031 russian
#    0.031 synonym
#    0.031 clauses
#    0.031 compositionality
#    0.031 agglutinative
#    0.031 basque
#    0.030 words
#    0.030 opinion
#    0.030 linguistics
#    0.030 pp
#    0.030 utterances
#    0.030 phrases
#    0.029 mentions
#    0.029 tokenization
#    0.028 acts
#    0.028 adjectives
#    0.028 annotation
#    0.027 cohesion
#    0.027 verbal
#    0.027 collocations
#    0.027 adjectival
#    0.027 comma
# CV
#    0.376 stereo
#    0.250 photometric
#    0.244 pose
#    0.213 illumination
#    0.198 texture
#    0.176 rigid
#    0.175 deformable
#    0.171 monocular
#    0.145 appearance
#    0.142 shading
#    0.141 3d
#    0.138 articulated
#    0.135 contours
#    0.134 cameras
#    0.134 motion
#    0.132 registration
#    0.127 occlusion
#    0.116 specular
#    0.089 surfaces
#    0.088 projector
#    0.086 affine
#    0.086 scene
#    0.085 occlusions
#    0.082 uncalibrated
#    0.081 deblurring
#    0.078 matting
#    0.078 catadioptric
#    0.073 epipolar
#    0.073 saliency
#    0.069 calibration
#    0.068 panoramic
#    0.064 reflectance
#    0.064 reconstruction
#    0.063 nonrigid
#    0.063 subtraction
#    0.062 lighting
#    0.061 scenes
#    0.061 curvature
#    0.061 manifolds
#    0.060 priors
#    0.059 camera
#    0.059 contour
#    0.057 facial
#    0.055 silhouette
#    0.055 intensity
#    0.054 cluttered
#    0.052 riemannian
#    0.050 mosaics
#    0.049 defocus
#    0.049 imaging
#    0.048 patch
#    0.048 textures
#    0.048 volumetric
#    0.047 manifold
#    0.046 deformation
#    0.046 curved
#    0.046 hough
#    0.046 shadows
#    0.046 vision
#    0.045 morphable
#    0.045 correspondences
#    0.045 cuts
#    0.042 ultrasound
#    0.041 symmetry
#    0.041 omnidirectional
#    0.041 rgb
#    0.040 blur
#    0.040 illuminant
#    0.040 mosaicing
#    0.040 shapes
#    0.039 surface
#    0.039 occluded
#    0.039 slam
#    0.039 snakes
#    0.039 tracker
#    0.039 moving
#    0.038 geodesic
#    0.038 cosegmentation
#    0.038 lidar
#    0.037 crowded
#    0.037 denoising
#    0.036 constancy
#    0.036 refractive
#    0.035 variational
#    0.034 invariant
#    0.034 projective
#    0.034 egomotion
#    0.034 rectification
#    0.033 autocalibration
#    0.033 restoration
#    0.033 cues
#    0.033 keypoint
#    0.033 occluding
#    0.032 reflection
#    0.032 binocular
#    0.032 depth
#    0.032 discriminant
#    0.031 tensor
#    0.031 detectors
#    0.031 inpainting
#    0.031 pde
#    0.031 stereoscopic
#    0.031 radiometric
#    0.031 blurred
#    0.031 brdf
#    0.031 mumford
#    0.031 shah
#    0.031 shutter
#    0.031 superpixels
#    0.031 cue
#    0.031 gait
#    0.030 body
#    0.030 planar
#    0.030 faces
#    0.030 sparse
#    0.029 medial
#    0.029 trifocal
#    0.028 surveillance
#    0.028 motions
#    0.028 cortical
#    0.028 lambertian
#    0.028 gradient
#    0.027 fingerprint
#    0.027 mrfs
#    0.027 optic
#    0.027 textured
#    0.027 foreground
#    0.027 mri
#    0.027 patches
#    0.027 perceptual
#    0.027 recovering
#    0.027 parametric
#    0.026 biometrics
#    0.026 ray
#    0.026 aperture
#    0.026 gabor
#    0.026 albedo
#    0.026 chromaticity
#    0.026 curvilinear
#    0.026 subdivision
#    0.026 aerial
#    0.025 outdoor
#    0.025 shadow
#    0.025 invariance
#    0.025 morphological
#    0.024 cylinders
#    0.024 diffeomorphic
#    0.024 vanishing
#    0.024 rendering
#    0.024 deformations
# COM
#    0.409 802
#    0.309 atm
#    0.300 wdm
#    0.298 packet
#    0.280 multicast
#    0.223 tcp
#    0.163 lans
#    0.153 congestion
#    0.138 wavelength
#    0.124 delay
#    0.117 multihop
#    0.115 queueing
#    0.101 lan
#    0.096 qos
#    0.094 csma
#    0.089 routing
#    0.084 cdma
#    0.082 routers
#    0.075 bgp
#    0.073 vbr
#    0.072 slotted
#    0.070 dqdb
#    0.069 admission
#    0.068 sensor
#    0.068 switches
#    0.066 wlans
#    0.065 11
#    0.065 isdn
#    0.065 mpls
#    0.063 lightwave
#    0.063 hop
#    0.061 tdma
#    0.060 antennas
#    0.058 protocols
#    0.057 bandwidth
#    0.057 handoff
#    0.056 abr
#    0.056 diffserv
#    0.056 wimax
#    0.056 router
#    0.054 ipv6
#    0.053 forwarding
#    0.053 protocol
#    0.051 fairness
#    0.051 buffered
#    0.049 downlink
#    0.049 queued
#    0.049 broadband
#    0.048 arq
#    0.048 ofdma
#    0.045 handover
#    0.045 lifetime
#    0.045 radio
#    0.045 queue
#    0.044 ieee
#    0.043 reservation
#    0.043 wlan
#    0.041 scheduling
#    0.041 fair
#    0.041 aloha
#    0.041 openflow
#    0.040 switch
#    0.040 relay
#    0.040 mesh
#    0.039 carrier
#    0.038 multicasting
#    0.037 sip
#    0.037 umts
#    0.037 survivable
#    0.037 service
#    0.036 manets
#    0.036 buffer
#    0.036 aqm
#    0.036 fddi
#    0.034 switched
#    0.034 retransmission
#    0.034 fading
#    0.034 flooding
#    0.033 3g
#    0.033 rings
#    0.032 arrivals
#    0.032 vehicular
#    0.031 ethernet
#    0.031 hosts
#    0.031 differentiated
#    0.031 16
#    0.031 banyan
#    0.031 multihoming
#    0.031 routed
#    0.030 priority
#    0.030 multiplexing
#    0.030 mimo
#    0.029 cellular
#    0.029 deflection
#    0.029 dimensioning
#    0.029 osi
#    0.029 uplink
#    0.029 bus
#    0.029 interference
#    0.028 energy
#    0.028 bittorrent
#    0.027 dtn
#    0.027 transmissions
#    0.027 networking
#    0.026 receiver
#    0.026 wifi
#    0.026 ip
#    0.026 queues
#    0.026 manet
#    0.026 multiplexer
#    0.026 ospf
#    0.026 rerouting
#    0.026 sdn
#    0.026 wired
#    0.025 backbone
#    0.024 ofdm
#    0.024 schedulers
#    0.024 pcs
#    0.024 caching
#    0.024 multipath
#    0.024 underwater
#    0.024 rfid
#    0.024 metropolitan
#    0.024 buffers
#    0.024 11e
#    0.024 grooming
#    0.024 internetworking
#    0.024 mans
#    0.024 multirate
#    0.024 photonic
#    0.024 wsns
#    0.023 unicast
#    0.023 provisioning
#    0.023 selfish
#    0.022 opportunistic
#    0.022 telephony
#    0.022 relaying
#    0.022 stateless
#    0.021 broadcasting
#    0.021 queuing
#    0.021 optical
#    0.020 slot
#    0.020 11b
#    0.020 datagram
#    0.020 interworking
#    0.020 retransmissions
#    0.020 skype
#    0.020 vegas
#    0.020 zigbee
#    0.020 token

# %%
#for paper_id, meta in paper.items():
#    if 'sigir' in str.lower(meta['title']):
#        print(meta['title'])

# %%
#key_ = ["WWW_keyword", "WWW_score", "ML_keyword", "ML_score", "DM_keyword", "DM_score", "IR_keyword", "IR_score", "DB_keyword", "DB_score", "HI_keyword", "HI_score", "NLP_keyword", "NLP_score", "CV_keyword", "CV_score", "COM_keyword", "COM_score", "OS_keyword", "OS_score"]
key_ = ["WWW_keyword", "WWW_score", "ML_keyword", "ML_score", "DM_keyword", "DM_score", "IR_keyword", "IR_score", "DB_keyword", "DB_score", "HI_keyword", "HI_score", "NLP_keyword", "NLP_score", "CV_keyword", "CV_score", "COM_keyword", "COM_score"]
val_ = []
for idx in range(n_clusters):
    val_.append([keyword for keyword, score in keyword_tfidf_cluster_list[idx].items()])
    val_.append([score for keyword, score in keyword_tfidf_cluster_list[idx].items()])
dic = {key_[i] : val_[i] for i in range(len(key_))}
df = pd.DataFrame(dic)
df.to_csv("field_tfidf.csv")
df.head()
# Out:
#   WWW_keyword  WWW_score  ML_keyword  ML_score  DM_keyword  DM_score  \
# 0         rdf   0.502531     spiking  0.289213         cup  0.384815
# 1         owl   0.382361     neurons  0.235184    itemsets  0.337786
# 2      sparql   0.347119        mdps  0.190355         kdd  0.312012
# 3         xml   0.164650  plasticity  0.143927  microarray  0.100161
# 4     service   0.118212    gaussian  0.133290     climate  0.098804
#
#     IR_keyword  IR_score DB_keyword  DB_score HI_keyword  HI_score  \
# 0        sigir  0.227365        xml  0.377105        hci  0.257121
# 1  recommender  0.226827       dbms  0.234718   tabletop  0.249299
# 2          xml  0.192153     xquery  0.214779   tangible  0.245884
# 3        ntcir  0.176840      xpath  0.211990       cscw  0.170654
# 4      passage  0.164208      joins  0.207440   pointing  0.163923
#
#   NLP_keyword  NLP_score    CV_keyword  CV_score COM_keyword  COM_score
# 0         smt   0.227614        stereo  0.375755         802   0.408592
# 1      parser   0.216421   photometric  0.249552         atm   0.309139
# 2    treebank   0.216040          pose  0.243509         wdm   0.299634
# 3    dialogue   0.209502  illumination  0.212713      packet   0.297829
# 4   adjoining   0.189035       texture  0.198239   multicast   0.279607

# %%
#用いるキーワード数
n_used_keyword = 50
field_used_keyword = {}

field_attribute = np.zeros((len(field_list), 300))
for field in range(n_clusters):
    vector = np.zeros((300))
    n_word = 0
    #weight = n_used_keyword
    weight = 0
    used_keyword = []
    for word in val_[field * 2]:
        try:
            #vector = vector + weight * word2vec[word]
            w = keyword_tfidf_cluster_list[field][word]
            vector = vector + w * word2vec[word]
            n_word += 1
            #weight -= 1
            weight += w
            used_keyword.append(word)
            #print(word)
        except KeyError as error:
            pass
            #print(word)
        if n_word == n_used_keyword:
            break
    if n_word == 0 or n_word < n_used_keyword:
        print("あり得ない")
        field_attribute[field] = vector
    else:
        #field_attribute[field] = vector / sum(i for i in range(1, n_used_keyword+1))
        field_attribute[field] = vector / weight
    field_used_keyword[field_list[field]] = used_keyword

# %%
df = pd.DataFrame(field_used_keyword)
df.to_csv("used_word.csv")

# %%
print(field_attribute.shape)
print(node_attribute.shape)
# Out:
# (9, 300)
# (99198, 300)

# %%
import sklearn
node_attribute_similar2field = sklearn.metrics.pairwise.cosine_similarity(node_attribute, field_attribute)
node_attribute_similar2field.shape
# Out:
# (99198, 9)

# %%
# 低次元に写像しクラスタを可視化
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
node_attribute_pca = pca.fit_transform(node_attribute_similar2field)
print(node_attribute_pca.shape)
# Out:
# (99198, 2)

# %%
x_field = [[] for _ in range(n_clusters)]
y_field = [[] for _ in range(n_clusters)]
for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    i = field_list.index(field)
    x_field[i].append(node_attribute_pca[node_idx_table[paper_id]][0])
    y_field[i].append(node_attribute_pca[node_idx_table[paper_id]][1])

# %%
import matplotlib.colors as mcolors
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
colors = [val for key, val in mcolors.TABLEAU_COLORS.items()]

for i in range(n_clusters):
    ax.scatter(x_field[i], y_field[i], c=colors[i], label=field_list[i])

ax.legend()
fig.savefig('scatter_sim2refvec.pdf')

# %%
# 低次元に写像しクラスタを可視化
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
field_attribute_pca = pca.fit_transform(field_attribute)
print(field_attribute_pca.shape)
# Out:
# (9, 2)

# %%
import matplotlib.colors as mcolors
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
colors = [val for key, val in mcolors.TABLEAU_COLORS.items()]

for i in range(n_clusters):
    ax.scatter(field_attribute_pca[i][0], field_attribute_pca[i][1], c=colors[i], label=field_list[i])
    plt.annotate(field_list[i], xy=(field_attribute_pca[i][0]-0.03, field_attribute_pca[i][1]+0.03))

fig.savefig('scatter_field.pdf')

# %%
# ここで実際の分野とタイトルのそれらしさの一致率をチェック
for paper_id, meta in sorted(paper.items())[:10]:
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    print(field, field_list[node_attribute_similar2field[node_idx_table[paper_id]].argmax()])
    print(meta['title'])
# Out:
# HI DM
# How dangerous is looking away from the road? Algorithms predict crash risk from glance patterns in naturalistic driving.
# ML CV
# Constructing Prioritized Fuzzy Models
# IR IR
# Operational requirements for scalable search systems
# HI HI
# Designing mobile phone interface with children
# NLP HI
# Training Tree Transducers.
# IR DM
# Exploring group mobility for replica data allocation in a mobile environment
# NLP WEB
# A Logic-Based Semantic Approach to Recognizing Textual Entailment
# COM DM
# A study of LBS accuracy in the UK and a novel approach to inferring the positioning technology employed
# IR IR
# A relational algebra for data/metadata integration in a federated database system
# WEB IR
# Finding the achilles heel of the web of data: using network analysis for link-recommendation

# %%
node_attribute_similar2field
# Out:
# array([[0.32663211, 0.25414111, 0.26904624, ..., 0.26538527, 0.38358526,
#         0.27365486],
#        [0.43854918, 0.32174033, 0.44086763, ..., 0.38021403, 0.30401785,
#         0.40324552],
#        [0.41867494, 0.39387416, 0.41515054, ..., 0.42705986, 0.53192956,
#         0.24534794],
#        ...,
#        [0.35346802, 0.32874911, 0.37507593, ..., 0.28527034, 0.401406  ,
#         0.38010597],
#        [0.45647137, 0.40551553, 0.48047494, ..., 0.35914567, 0.37040385,
#         0.44280612],
#        [0.41176825, 0.38641633, 0.42640877, ..., 0.26760688, 0.30745986,
#         0.39070137]])

# %%
rows = []
for idx, ts in enumerate(years):
    rows.append([ts, idx])
df = pd.DataFrame(rows, columns=['TS', 'ID'])
df.to_csv(outputDir + '/ts_idx.csv', index=False, encoding='utf_8_sig')

# %%
df = pd.read_csv(outputDir + '/ts_idx.csv')
df_TS = df.TS.values
df_ID = df.ID.values
ts_idx_table = {}
for row in range(df.shape[0]):
    ts_idx_table[df_TS[row]] = df_ID[row]

# %%
exist_table = np.zeros((len(node_idx_table), len(ts_idx_table)))
for year in years:
    for paper_id, meta in paper.items():
        if year < meta['year']:
            exist_table[node_idx_table[paper_id]][ts_idx_table[year]] = 0
        else:
            exist_table[node_idx_table[paper_id]][ts_idx_table[year]] = 1

np.save(outputDir + '/exist_table', exist_table)

# %%
for year in years:
    node_attribute = np.zeros((len(node_idx_table), len(field_list)))
    index = exist_table[:, ts_idx_table[year]] == 1
    node_attribute[index] = node_attribute_similar2field[index]
    np.save(outputDir + '/node_attribute' + str(ts_idx_table[year]), node_attribute)

# %%
for year in years:
    adjacency = lil_matrix((len(node_idx_table), len(node_idx_table)))
    for paper_id, meta in paper.items():
        if year < meta['year']:
            continue
        for reference_id in meta['references']:
            if not reference_id in node_idx_table.keys():
                continue
            adjacency[node_idx_table[paper_id], node_idx_table[reference_id]] = 1
    mmwrite(outputDir + '/adjacency' + str(ts_idx_table[year]), adjacency)

# %%
exist_table.shape
# Out:
# (127980, 50)

# %%
exist_table[:, -1] == 1
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
node_attribute_similar2field.shape
# Out:
# (127980, 9)

# %%
len(field_list)
# Out:
# 9

# %%
# 従来の問題点1 : connected component は1だが、必ずしもnew nodeのreference先が存在するとは限らない
# 従来の問題点2 : 今回はnew node予測のみなので必ずしもexisting node の隣接行列等は必要ない
# 従来の問題点3 : サイズが大きすぎてdeep learningができない
# 従来の問題点4 : 属性のその他が多すぎる問題

# 方針1 : new nodeがreference先を1つ以上持つものをサンプリングする
# 方針2 : original (2118551)のグラフが持つ属性の割合を保持する (e.g. 1990年はdb:0.8, ml:0.2、1990年はdb:0.6, ml:0.4、・・・) ようにnew nodeをサンプリングする
# 方針3 : 方針1と方針2を満たすnew nodeとそのreference先のセットを1サンプルとする

# 方針3で作成されたグラフを時系列に組み合わせて新たな時系列グラフを作り直す。
# ただし、各サンプル（各タイムステップ）のexisting node（reference先のノード）はそのタイミングのみ存在するものとする。
# 次のタイミングでは過去のnew nodeもexisting nodeも消失ノードとする（new node 予測のみなので、消失予測は関係無い）
# new node & existing nodeが新たに出現し、すぐさま消失するイメージ
# new nodeの出現数もoriginalの等縮小倍率とする
#（本当は過去ノードは消失ノード扱いのため存在していないが）グラフとしてはサブサンプルされたnew node & existing nodeの累積個数とする。
# この方法で作成すれば一応、new nodeの数と属性の統計量を保持したままグラフを削れる

# → まずはグラフサイズを削る前に年ごとの属性の割合を明らかにする

# %%
# 年ごとのpaper_id の辞書を作成
year_paper_dic = {}
for year in years:
    year_paper_dic[year] = []
for paper_id, meta in paper.items():
    year_paper_dic[meta['year']].append(paper_id)

# 年ごとのnew nodeの数を表示
for year in years:
    print(year, len(year_paper_dic[year]))

# %%
node_attribute = np.zeros((len(node_idx_table), 300))
for paper_id, meta in paper.items():
    vector = np.zeros((300))
    #print(meta['title'])
    n_word = 0
    for word in meta['title'].split(' '):
        try:
            vector = vector + word2vec[word]
            n_word += 1
            #print(word)
        except KeyError as error:
            pass
            #print(error)
    if n_word == 0:
        node_attribute[node_idx_table[paper_id]] = vector
    else:
        node_attribute[node_idx_table[paper_id]] = vector / n_word
    #print(node_attribute[node_idx_table[paper_id]])
    #print(" ")

# %%
# zero vectorの件数 (タイトル内のどの単語もword2vecのカバー範囲に含まれなかった件数)
sum(np.abs(node_attribute.sum(axis=1)) < 0.0000001)

# %%
from sklearn.cluster import MiniBatchKMeans
n_clusters = 10
kmeans_model = MiniBatchKMeans(n_clusters=n_clusters, batch_size=3000, random_state=42, max_iter=1000000, max_no_improvement=10000)
kmeans_model.fit(node_attribute)

# %%
kmeans_model.labels_

# %%
# 論文のラベルとしてcluster key を追加
for paper_id, meta in paper.items():
    paper[paper_id]["cluster"] = kmeans_model.labels_[node_idx_table[paper_id]]

# %%
# クラスタごとの論文を抽出して連結し文書化する。

def Isalnum(s):
    alnumReg = re.compile(r'^[a-zA-Z0-9]+$')
    return alnumReg.match(s) is not None

cluster_title_list = [[] for _ in range(n_clusters)]
for paper_id, meta in paper.items():
    cluster_title_list[meta['cluster']].append(meta['title'])

documents = []
for title_list in cluster_title_list:
    title_list = ' '.join(title_list)
    title_list = str.lower(title_list)
    notalnum = set()
    for s in set(title_list):
        if s != ' ' and not Isalnum(s):
            notalnum.add(s)
            #print(s) # 記号（文字や数値でないもの）
    for s in notalnum:
        title_list = title_list.replace(s, ' ')
    documents.append(title_list)

# %%
# TF-IDFを計算し、各クラスタごとの代表的な単語を上位数件表示する。

from gensim import corpora
from gensim import models

# gensim用に整形
texts = list(map(lambda x:x.split(),documents))

# 単語->id変換の辞書作成
dictionary = corpora.Dictionary(texts)
#print(dictionary.token2id)

# textsをcorpus化
corpus = list(map(dictionary.doc2bow,texts))
#print(corpus)

# tfidf modelの生成
test_model = models.TfidfModel(corpus)

# corpusへのモデル適用
corpus_tfidf = test_model[corpus]

texts_tfidf = []
for doc in corpus_tfidf:
    text_tfidf = []
    for word in doc:
        text_tfidf.append((dictionary[word[0]],word[1]))
    texts_tfidf.append(text_tfidf)

keyword_tfidf_cluster_list = []
for idx, text in enumerate(texts_tfidf):
    print('cluster:', idx)
    keyword_tfidf_cluster_list.append({})
    for keyword in sorted(text, key=lambda x:(x[1]), reverse=True)[:10]:
        print('   %.3f %s' %(keyword[1], keyword[0]))
        keyword_tfidf_cluster_list[idx][keyword[0]] = keyword[1]

# %%
keyword_tfidf_cluster_list

# %%
# !pip install cmake
# !pip install MulticoreTSNE

# %%
# 低次元に写像しクラスタを可視化（めちゃくちゃ遅い！！！）
from MulticoreTSNE import MulticoreTSNE as TSNE
import multiprocessing

print(multiprocessing.cpu_count())
t_sne = TSNE(n_jobs=multiprocessing.cpu_count()).fit_transform(node_attribute)
print('t_sne shape:', t_sne.shape)

# %%
aaa

# %%
# 年ごとのクラスタの割合をプロット (Deep MatchMaxが学習できるヒントがあるかもしれない)

# %%
aaa

# %%
# pandas 高速化 https://kunai-lab.hatenablog.jp/entry/2018/04/08/134924
df = pd.read_csv(outputDir + '/node_idx.csv')
df_node = df.node.values
df_ID = df.ID.values
node_idx_table2 = {}
for row in range(df.shape[0]):
    node_idx_table2[df_node[row]] = df_ID[row]
assert node_idx_table2 == node_idx_table, "いってこいになってない"

del df, df_node, df_ID, node_idx_table2, connected_component, sg, max_sg, paper_id_set, G, paper
gc.collect()

# %%
paper = {}
for file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:
#for file in ['dblp-ref-3.json']:
    with open(os.path.join(aminer_dir, file)) as f:
        for line in f:
            empty_flag = 0
            data = json.loads(line)
            paper_id = data.pop('id')
            if not paper_id in node_idx_table:
                continue
            if attribute_set & data.keys() != attribute_set:
                continue
            for attribute in attribute_set:
                if attribute == 'year' or attribute == 'n_citation':
                    continue
                if len(data[attribute]) == 0:
                    empty_flag = 1
            if empty_flag == 0:
                paper[paper_id] = data

len(paper)

# %%
dict_id2title = {}
for paper_id in paper.keys():
    dict_id2title[paper_id] = paper[paper_id]['title']
len(dict_id2title)

# %%
venue_dict = {}
for paper_id, meta in paper.items():
    if meta['venue'] in venue_dict.keys():
        venue_dict[meta['venue']] = venue_dict[meta['venue']] + 1
    else:
        venue_dict[meta['venue']] = 1

venue_list = []
for name, count in sorted(venue_dict.items(), key=lambda x: -x[1]):
    venue_list.append(name)

# %%
def GetListIndex(l, x, default=-1):
    if x in l:
        return l.index(x)
    else:
        return default

def Isalnum(s):
    alnumReg = re.compile(r'^[a-zA-Z0-9]+$')
    return alnumReg.match(s) is not None

venue_list = venue_list[:100]
title_groupby_venue_defaultdict = defaultdict(list)
for paper_id, meta in paper.items():
    if GetListIndex(venue_list, meta['venue']) != -1:
        title_groupby_venue_defaultdict[meta['venue']].append(meta['title'])

document_groupby_venue_dict = {}
for venue in venue_list:
    title_list = title_groupby_venue_defaultdict[venue]
    title_list = ' '.join(title_list)
    title_list = str.lower(title_list)
    notalnum = []
    for s in title_list:
        if s != ' ' and not Isalnum(s):
            notalnum.append(s)
            #print(s) # 記号（文字や数値でないもの）
    for s in notalnum:
        title_list = title_list.replace(s, ' ')
    document_groupby_venue_dict[venue] = title_list

# %%
rows = []
row = ['field', 0, 0, 100, 'VECTOR', True, False, False]
row.extend(sorted(venue_list))
row.extend(['other'])
rows.append(row)
columns = ['name', 'ID', 'range0', 'range1', 'type', 'primary', 'avg', 'cov']
classes = ['class' + str(i) for i in range(len(venue_list) + 1)]
columns.extend(classes)
df = pd.DataFrame(rows, columns=columns)
df.to_csv(outputDir + '/attribute_idx.csv', index=False, encoding='utf_8_sig')

# %%
from gensim import corpora
from gensim import models

documents = []
for venue in venue_list:
    documents.append(document_groupby_venue_dict[venue])
    
# gensim用に整形
texts = list(map(lambda x:x.split(),documents))

# 単語->id変換の辞書作成
dictionary = corpora.Dictionary(texts)
#print(dictionary.token2id)

# textsをcorpus化
corpus = list(map(dictionary.doc2bow,texts))
#print(corpus)

# tfidf modelの生成
test_model = models.TfidfModel(corpus)

# corpusへのモデル適用
corpus_tfidf = test_model[corpus]

texts_tfidf = []
for doc in corpus_tfidf:
    text_tfidf = []
    for word in doc:
        text_tfidf.append((dictionary[word[0]],word[1]))
    texts_tfidf.append(text_tfidf)

keyword_tfidf_venue_dict = {}
for idx, text in enumerate(texts_tfidf):
    print(venue_list[idx])
    keyword_tfidf_venue_dict[venue_list[idx]] = {}
    for keyword in sorted(text, key=lambda x:(x[1]), reverse=True)[:10]:
        print('   %.3f %s' %(keyword[1], keyword[0]))
        keyword_tfidf_venue_dict[venue_list[idx]][keyword[0]] = keyword[1]

# %%
title_venue_score = {}
for paper_id, meta in paper.items():
    title_venue_score[meta['title']] = {}
    word_list = meta['title'].split(' ')
    for venue, tfidf in keyword_tfidf_venue_dict.items():
        title_venue_score[meta['title']][venue] = 0
        for keyword, score in tfidf.items():
            for word in word_list:
                if keyword == str.lower(word):
                    title_venue_score[meta['title']][venue] = title_venue_score[meta['title']][venue] + score

# %%
title_venue_dict = {}
number = 0
for title, venue_score_dict in title_venue_score.items():
    number += 1
    if number < 100:
        print(title)
    for venue, score in sorted(venue_score_dict.items(), key=lambda x: x[1], reverse=True)[:5]:
        if number < 100:
            print('   %.3f %s' %(score, venue))
    #venue, score = sorted(venue_score_dict.items(), key=lambda x: x[1], reverse=True)[0]
    #if score == 0:
    #    title_venue_dict[title] = 'other'
    #    continue
    #title_venue_dict[title] = venue

# %%
title_venue_dict = {}
for title, venue_score_dict in title_venue_score.items():
    #title_venue_dict[title] = [0 for _ in range(len(venue_list))]
    title_venue_dict[title] = {}
    for venue, score in venue_score_dict.items():
        #title_venue_dict[title][GetListIndex(venue_list, venue)] = score
        title_venue_dict[title][venue] = score
    #score_sum = sum(title_venue_dict[title])
    score_sum = sum([score for venue, score in title_venue_dict[title].items()])
    if score_sum == 0:
        continue
    #for idx, score in enumerate(title_venue_dict[title]):
    #    title_venue_dict[title][idx] = score / score_sum
    for venue, score in title_venue_dict[title].items():
        title_venue_dict[title][venue] = score / score_sum

for title, score_list in title_venue_dict.items():
    if title == 'Evolutionary Chaos Controller Synthesis for Stabilizing Chaotic Hénon Maps.':
        print(title)
        for venue, score in score_list.items():
            print(venue, score)

# %%
years = set()
for paper_id, meta in paper.items():
    years.add(paper[paper_id]['year'])
years = list(years)
years.sort()
years

# %%
rows = []
for idx, year in enumerate(years):
    rows.append([year, idx])
df = pd.DataFrame(rows, columns=['TS', 'ID'])
df.to_csv(outputDir + '/ts_idx.csv', index=False, encoding='utf_8_sig')

# %%
# pandas 高速化 https://kunai-lab.hatenablog.jp/entry/2018/04/08/134924
df = pd.read_csv(outputDir + '/ts_idx.csv')
df_TS = df.TS.values
df_ID = df.ID.values
ts_idx_table = {}
for row in range(df.shape[0]):
    ts_idx_table[df_TS[row]] = df_ID[row]
ts_idx_table

# %%
exist_table = np.zeros((len(node_idx_table), len(ts_idx_table)))
for year in years:
    for paper_id, meta in paper.items():
        if year < meta['year']:
            exist_table[node_idx_table[paper_id]][ts_idx_table[year]] = 0
        else:
            exist_table[node_idx_table[paper_id]][ts_idx_table[year]] = 1

np.save(outputDir + '/exist_table', exist_table)

# %%
for year in years:
    node_attribute = np.zeros((len(node_idx_table), len(venue_list)+1))
    for paper_id, meta in paper.items():
        if year < meta['year']:
            continue
        field_vector = []
        for veneu, score in sorted(title_venue_dict[meta['title']].items(), key=lambda x:x[0]):
            field_vector.append(score)
        field_vector.append(0)
        if sum(field_vector) == 0:
            field_vector[100] = 1
        node_attribute[node_idx_table[paper_id]] = np.array(field_vector)
    np.save(outputDir + '/node_attribute' + str(ts_idx_table[year]), node_attribute)

# %%
for year in years:
    adjacency = lil_matrix((len(node_idx_table), len(node_idx_table)))
    for paper_id, meta in paper.items():
        if year < meta['year']:
            continue
        for reference_id in meta['references']:
            if not reference_id in node_idx_table.keys():
                continue
            adjacency[node_idx_table[paper_id], node_idx_table[reference_id]] = 1
    mmwrite(outputDir + '/adjacency' + str(ts_idx_table[year]), adjacency)

# %%
date2 = datetime.datetime.now()
print(date2)
