# %%
import os
import numpy as np
import pandas as pd
import json
import gensim
import re
import pandas as pd
import gc
import networkx as nx
from scipy.sparse import lil_matrix
from scipy.io import mmwrite, mmread
from collections import defaultdict

aminer_dir = '../data/original'
outputDir = '../data/graph'
word2vec = gensim.models.KeyedVectors.load_word2vec_format('./data/word2vec/GoogleNews-vectors-negative300.bin', binary=True)
# Out:
# /Users/shohei/.pyenv/versions/anaconda3-5.3.0/envs/tensorenv/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
import datetime
date2 = datetime.datetime.now()
print(date2)
# Out:
# 2020-10-14 21:39:10.984085

# %%
#attribute_set = {'title', 'authors', 'venue', 'year', 'n_citation', 'references', 'abstract'}
attribute_set = {'title', 'venue', 'year', 'references'}

paper = {}
for file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:
#for file in ['dblp-ref-3.json']:
    with open(os.path.join(aminer_dir, file)) as f:
        for line in f:
            empty_flag = 0
            data = json.loads(line)
            paper_id = data.pop('id')
            if attribute_set & data.keys() != attribute_set:
                continue
            for attribute in attribute_set:
                if attribute == 'year' or attribute == 'n_citation':
                    continue
                if len(data[attribute]) == 0:
                    empty_flag = 1
            if empty_flag == 0:
                paper[paper_id] = data

len(paper)
# Out:
# 2154706

# %%
venue_list = list(pd.read_table("venue2.csv")['venue'])
venue_list = venue_list[:-4] # OSは除去
print(len(venue_list))
# Out:
# 56
# /Users/shohei/.pyenv/versions/anaconda3-5.3.0/envs/tensorenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
paper = {}
attribute_set = {'title', 'venue', 'year', 'references'}
for file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:
    with open(os.path.join(aminer_dir, file)) as f:
        for line in f:
            empty_flag = 0
            data = json.loads(line)
            paper_id = data.pop('id')
            if attribute_set & data.keys() != attribute_set:
                continue
            for attribute in attribute_set:
                if attribute == 'year' or attribute == 'n_citation':
                    continue
                if len(data[attribute]) == 0:
                    empty_flag = 1
            if empty_flag == 0:
                if data['venue'] in venue_list:
                    if data['year'] == 2017:
                        data['year'] = 2016
                    paper[paper_id] = data

len(paper)
# Out:
# 127980

# %%
venue_count_dic = {}
for venue in venue_list:
    venue_count_dic[venue] = 0

for paper_id, meta in paper.items():
    venue_count_dic[meta['venue']] += 1

# %%
""""
G = nx.Graph()
year = 2018
paper_id_set = set()

for paper_id, meta in paper.items():
    if year < meta['year']:
        continue
    paper_id_set.add(paper_id)
print("node num : ",len(paper_id_set))

for paper_id in paper_id_set:
    G.add_node(paper_id)
    for reference_id in paper[paper_id]['references']:
        if not reference_id in paper_id_set:
            continue
        G.add_edge(paper_id, reference_id)
print("edge num : ",len(G.edges))
"""
# Out:
# '"\nG = nx.Graph()\nyear = 2018\npaper_id_set = set()\n\nfor paper_id, meta in paper.items():\n    if year < meta[\'year\']:\n        continue\n    paper_id_set.add(paper_id)\nprint("node num : ",len(paper_id_set))\n\nfor paper_id in paper_id_set:\n    G.add_node(paper_id)\n    for reference_id in paper[paper_id][\'references\']:\n        if not reference_id in paper_id_set:\n            continue\n        G.add_edge(paper_id, reference_id)\nprint("edge num : ",len(G.edges))\n'

# %%
"""
connected_component = {}
max_scale = 0
for c in nx.connected_components(G):
    sg = G.subgraph(c)
    if max_scale < len(sg.nodes):
        max_scale = len(sg.nodes)
        max_sg = G.subgraph(c)
    if not len(sg.nodes) in connected_component.keys():
        connected_component[len(sg.nodes)] = 1
    else:
        connected_component[len(sg.nodes)] += 1
connected_component
"""
# Out:
# '\nconnected_component = {}\nmax_scale = 0\nfor c in nx.connected_components(G):\n    sg = G.subgraph(c)\n    if max_scale < len(sg.nodes):\n        max_scale = len(sg.nodes)\n        max_sg = G.subgraph(c)\n    if not len(sg.nodes) in connected_component.keys():\n        connected_component[len(sg.nodes)] = 1\n    else:\n        connected_component[len(sg.nodes)] += 1\nconnected_component\n'

# %%
"""
node_idx_table = {}
for idx, node in enumerate(max_sg.nodes):
    node_idx_table[node] = idx
"""
# Out:
# '\nnode_idx_table = {}\nfor idx, node in enumerate(max_sg.nodes):\n    node_idx_table[node] = idx\n'

# %%
node_idx_table = {}
for idx, node in enumerate(paper.keys()):
    node_idx_table[node] = idx

# %%
rows = []
for node, idx in node_idx_table.items():
    rows.append([node, idx])
df = pd.DataFrame(rows, columns=['node', 'ID'])
df.to_csv(outputDir + '/node_idx.csv', index=False, encoding='utf_8_sig')

# %%
"""
paper = {}
for file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:
#for file in ['dblp-ref-3.json']:
    with open(os.path.join(aminer_dir, file)) as f:
        for line in f:
            empty_flag = 0
            data = json.loads(line)
            paper_id = data.pop('id')
            if not paper_id in node_idx_table:
                continue
            if attribute_set & data.keys() != attribute_set:
                continue
            for attribute in attribute_set:
                if attribute == 'year' or attribute == 'n_citation':
                    continue
                if len(data[attribute]) == 0:
                    empty_flag = 1
            if empty_flag == 0:
                paper[paper_id] = data

len(paper)
"""
# Out:
# "\npaper = {}\nfor file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:\n#for file in ['dblp-ref-3.json']:\n    with open(os.path.join(aminer_dir, file)) as f:\n        for line in f:\n            empty_flag = 0\n            data = json.loads(line)\n            paper_id = data.pop('id')\n            if not paper_id in node_idx_table:\n                continue\n            if attribute_set & data.keys() != attribute_set:\n                continue\n            for attribute in attribute_set:\n                if attribute == 'year' or attribute == 'n_citation':\n                    continue\n                if len(data[attribute]) == 0:\n                    empty_flag = 1\n            if empty_flag == 0:\n                paper[paper_id] = data\n\nlen(paper)\n"

# %%
#venue_set = set()
#for paper_id, meta in paper.items():
#    venue_set.add(meta['venue'])

# %%
#df = pd.DataFrame({'venue': list(venue_set)})
#df.to_csv("venue.csv")

# %%
years = set()
for paper_id, meta in paper.items():
    years.add(paper[paper_id]['year'])
years = list(years)
years.sort()
years
# Out:
# [1965,
#  1967,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016]

# %%
#field_list = ["WEB", "ML", "DM", "IR", "DB", "HI", "NLP", "CV", "COM", "OS"]
field_list = ["WEB", "ML", "DM", "IR", "DB", "HI", "NLP", "CV", "COM"]
field_venue_dic = defaultdict(list)

for idx, venue in enumerate(venue_list):
    if idx < 5:
        field_venue_dic["WEB"].append(venue)
    elif idx < 12:
        field_venue_dic["ML"].append(venue)
    elif idx < 19:
        field_venue_dic["DM"].append(venue)
    elif idx < 25:
        field_venue_dic["IR"].append(venue)
    elif idx < 34:
        field_venue_dic["DB"].append(venue)
    elif idx < 42:
        field_venue_dic["HI"].append(venue)
    elif idx < 47:
        field_venue_dic["NLP"].append(venue)
    elif idx < 51:
        field_venue_dic["CV"].append(venue)
    elif idx < 56:
        field_venue_dic["COM"].append(venue)
    #else:
    #    field_venue_dic["OS"].append(venue)

field_venue_dic
# Out:
# defaultdict(list,
#             {'WEB': ['World Wide Web',
#               'international world wide web conferences',
#               'international semantic web conference',
#               'Journal of Web Semantics',
#               'european semantic web conference'],
#              'ML': ['Artificial Intelligence',
#               'international joint conference on artificial intelligence',
#               'international conference on neural information processing',
#               'neural information processing systems',
#               'international conference on machine learning',
#               'Machine Learning',
#               'international conference on learning representations'],
#              'DM': ['Sigkdd Explorations',
#               'Data Mining and Knowledge Discovery',
#               'workshop on knowledge discovery and data mining',
#               'knowledge discovery and data mining',
#               'international conference on data mining',
#               'siam international conference on data mining',
#               'web search and data mining'],
#              'IR': ['Sigir Forum',
#               'international acm sigir conference on research and development in information retrieval',
#               'Information Retrieval',
#               'conference on information and knowledge management',
#               'Journal of Information & Knowledge Management',
#               'conference on recommender systems'],
#              'DB': ['Sigmod Record',
#               'international conference on management of data',
#               'conference on management of data',
#               'symposium on principles of database systems',
#               'Proceedings of The Vldb Endowment',
#               'The Vldb Journal',
#               'very large data bases',
#               'international conference on data engineering',
#               'extending database technology'],
#              'HI': ['ACM Sigchi Bulletin',
#               'human factors in computing systems',
#               'Human Factors',
#               'intelligent user interfaces',
#               'european conference on computer supported cooperative work',
#               'Computer Supported Cooperative Work',
#               'conference on computer supported cooperative work',
#               'user interface software and technology'],
#              'NLP': ['Computational Linguistics',
#               'meeting of the association for computational linguistics',
#               'empirical methods in natural language processing',
#               'international conference on computational linguistics',
#               'north american chapter of the association for computational linguistics'],
#              'CV': ['computer vision and pattern recognition',
#               'international conference on computer vision',
#               'International Journal of Computer Vision',
#               'european conference on computer vision'],
#              'COM': ['acm special interest group on data communication',
#               'Computer Communications',
#               'international conference on computer communications',
#               'acm/ieee international conference on mobile computing and networking',
#               'acm ieee international conference on mobile computing and networking']})

# %%
field_count_dic = {}
for field in field_list:
    field_count_dic[field] = 0

for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    field_count_dic[field] += 1

field_count_dic
# Out:
# {'WEB': 7644,
#  'ML': 21088,
#  'DM': 10997,
#  'IR': 9427,
#  'DB': 14657,
#  'HI': 17919,
#  'NLP': 12746,
#  'CV': 18980,
#  'COM': 14522}

# %%
year_field_count = np.zeros((len(years), len(field_list)))
for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    year_field_count[years.index(meta['year'])][field_list.index(field)] +=1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

for f_idx in range(len(field_list)):
    plt.plot(years, year_field_count[:, f_idx], label=field_list[f_idx])
plt.xlabel("year")
plt.ylabel("the # of papers")
plt.legend()
plt.savefig("num_of_paper_field.pdf")

# %%
plt.figure()
plt.plot(years, year_field_count.sum(axis=1))
plt.xlabel("year")
plt.ylabel("the # of papers")
plt.savefig("num_of_paper.pdf")

# %%
node_attribute = np.zeros((len(node_idx_table), 300))
for paper_id, meta in paper.items():
    vector = np.zeros((300))
    #print(meta['title'])
    n_word = 0
    for word in meta['title'].split(' '):
        try:
            vector = vector + word2vec[word]
            n_word += 1
            #print(word)
        except KeyError as error:
            pass
            #print(error)
    if n_word == 0:
        node_attribute[node_idx_table[paper_id]] = vector
    else:
        node_attribute[node_idx_table[paper_id]] = vector / n_word
    #print(node_attribute[node_idx_table[paper_id]])
    #print(" ")

# %%
# 低次元に写像しクラスタを可視化
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
node_attribute_pca = pca.fit_transform(node_attribute)
print(node_attribute_pca.shape)
# Out:
# (127980, 2)

# %%
n_clusters = len(field_list)
x_field = [[] for _ in range(n_clusters)]
y_field = [[] for _ in range(n_clusters)]
for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    i = field_list.index(field)
    x_field[i].append(node_attribute_pca[node_idx_table[paper_id]][0])
    y_field[i].append(node_attribute_pca[node_idx_table[paper_id]][1])

# %%
import matplotlib.colors as mcolors
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
colors = [val for key, val in mcolors.TABLEAU_COLORS.items()]

for i in range(n_clusters):
    ax.scatter(x_field[i], y_field[i], c=colors[i], label=field_list[i])

ax.legend()
fig.savefig('scatter_word2vec.pdf')

# %%
# 分野ごとの論文を抽出して連結し文書化する。

def Isalnum(s):
    alnumReg = re.compile(r'^[a-zA-Z0-9]+$')
    return alnumReg.match(s) is not None

n_clusters = len(field_list)

cluster_title_list = [[] for _ in range(n_clusters)]
for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    cluster_title_list[field_list.index(field)].append(meta['title'])

documents = []
for title_list in cluster_title_list:
    title_list = ' '.join(title_list)
    title_list = str.lower(title_list)
    notalnum = set()
    for s in set(title_list):
        if s != ' ' and not Isalnum(s):
            notalnum.add(s)
            #print(s) # 記号（文字や数値でないもの）
    for s in notalnum:
        title_list = title_list.replace(s, ' ')
    documents.append(title_list)

# %%
# TF-IDFを計算し、各クラスタごとの代表的な単語を上位数件表示する。

from gensim import corpora
from gensim import models

# gensim用に整形
texts = list(map(lambda x:x.split(),documents))

# 単語->id変換の辞書作成
dictionary = corpora.Dictionary(texts)
#print(dictionary.token2id)

# textsをcorpus化
corpus = list(map(dictionary.doc2bow,texts))
#print(corpus)

# tfidf modelの生成
test_model = models.TfidfModel(corpus)

# corpusへのモデル適用
corpus_tfidf = test_model[corpus]

texts_tfidf = []
for doc in corpus_tfidf:
    text_tfidf = []
    for word in doc:
        text_tfidf.append((dictionary[word[0]],word[1]))
    texts_tfidf.append(text_tfidf)

keyword_tfidf_cluster_list = []
for idx, text in enumerate(texts_tfidf):
    print(field_list[idx])
    keyword_tfidf_cluster_list.append({})
    for keyword in sorted(text, key=lambda x:(x[1]), reverse=True)[:150]:
        print('   %.3f %s' %(keyword[1], keyword[0]))
        keyword_tfidf_cluster_list[idx][keyword[0]] = keyword[1]
# Out:
# WEB
#    0.494 rdf
#    0.383 owl
#    0.341 sparql
#    0.120 restful
#    0.116 service
#    0.102 ontologies
#    0.084 rdfs
#    0.079 r2rml
#    0.079 skos
#    0.076 wikipedia
#    0.070 xml
#    0.070 bioportal
#    0.069 caching
#    0.061 publishing
#    0.061 lod
#    0.061 oaei
#    0.057 daml
#    0.054 xslt
#    0.053 dl
#    0.052 lifecycle
#    0.052 dbpedia
#    0.050 twitter
#    0.048 rl
#    0.045 enterprise
#    0.044 scholarly
#    0.044 endpoints
#    0.044 observatories
#    0.044 smil
#    0.044 webml
#    0.042 federated
#    0.042 folksonomy
#    0.040 pagerank
#    0.040 reasoner
#    0.039 mashups
#    0.039 observatory
#    0.039 provenance
#    0.039 apis
#    0.039 mashup
#    0.037 html
#    0.035 javascript
#    0.035 matchmaking
#    0.035 irs
#    0.035 matchmaker
#    0.035 mediawiki
#    0.035 metamodeling
#    0.035 nucleus
#    0.035 rdfa
#    0.035 sameas
#    0.035 sawsdl
#    0.035 wsmo
#    0.034 p2p
#    0.034 authoring
#    0.033 multilingual
#    0.033 dc
#    0.033 folksonomies
#    0.032 entailment
#    0.032 http
#    0.032 hypermedia
#    0.032 metadata
#    0.031 plugin
#    0.031 prot
#    0.031 ql
#    0.031 ws
#    0.031 xquery
#    0.030 heritage
#    0.030 tweets
#    0.030 interlinking
#    0.030 pdas
#    0.029 rewriting
#    0.029 wikis
#    0.029 crawling
#    0.029 linking
#    0.028 reviews
#    0.026 ajax
#    0.026 blank
#    0.026 bpel4ws
#    0.026 chatty
#    0.026 choreography
#    0.026 dbin
#    0.026 dns
#    0.026 dolce
#    0.026 gazetteer
#    0.026 gnowsis
#    0.026 gsp
#    0.026 hdt
#    0.026 isparql
#    0.026 lemon
#    0.026 liteq
#    0.026 nohr
#    0.026 odesew
#    0.026 onki
#    0.026 ontop
#    0.026 ourspaces
#    0.026 potluck
#    0.026 qakis
#    0.026 sambo
#    0.026 scientometrics
#    0.026 shop2
#    0.026 sina
#    0.026 sitemaps
#    0.026 templating
#    0.026 uris
#    0.026 veracity
#    0.026 wsmx
#    0.026 xpath
#    0.026 yago
#    0.026 zhishi
#    0.026 auctions
#    0.026 browsers
#    0.026 middleware
#    0.026 qos
#    0.026 crawler
#    0.025 named
#    0.024 cookies
#    0.024 datatypes
#    0.024 demonstrator
#    0.024 homepage
#    0.024 oxpath
#    0.024 sentiment
#    0.023 lite
#    0.023 museum
#    0.023 posts
#    0.023 sciences
#    0.023 triples
#    0.023 captcha
#    0.023 executing
#    0.023 thesauri
#    0.023 w3c
#    0.022 engines
#    0.022 advertiser
#    0.022 bpel
#    0.022 disasters
#    0.022 interlinked
#    0.022 misinformation
#    0.022 reasoners
#    0.022 signing
#    0.021 browser
#    0.021 recommender
#    0.021 mediation
#    0.021 faceted
#    0.021 ecosystem
#    0.020 analytics
#    0.020 natural
#    0.020 academic
#    0.019 bookmarking
#    0.019 copyright
#    0.019 earthquake
#    0.019 endpoint
#    0.019 freebase
#    0.019 mash
# ML
#    0.323 spiking
#    0.251 neurons
#    0.171 mdps
#    0.150 plasticity
#    0.129 variational
#    0.122 neuron
#    0.109 spike
#    0.098 bandits
#    0.096 cortical
#    0.095 cortex
#    0.093 reinforcement
#    0.090 pomdps
#    0.089 nonmonotonic
#    0.087 synaptic
#    0.086 stochastic
#    0.082 covariance
#    0.082 csps
#    0.082 firing
#    0.080 kernels
#    0.079 circumscription
#    0.079 backpropagation
#    0.075 proving
#    0.074 regularization
#    0.074 factored
#    0.073 autoepistemic
#    0.072 lasso
#    0.071 csp
#    0.067 chaotic
#    0.063 mlp
#    0.062 hippocampal
#    0.062 silicon
#    0.062 minimax
#    0.061 motor
#    0.059 equilibrium
#    0.058 priors
#    0.056 hebbian
#    0.055 logics
#    0.055 abduction
#    0.055 nonnegative
#    0.054 apprenticeship
#    0.054 stdp
#    0.053 bandit
#    0.052 equilibria
#    0.052 existential
#    0.052 receptive
#    0.052 multiagent
#    0.051 ai
#    0.051 satisfiability
#    0.050 analog
#    0.050 epistemic
#    0.050 sensorimotor
#    0.050 synapses
#    0.050 ica
#    0.049 natural
#    0.048 neuronal
#    0.048 saliency
#    0.048 regularized
#    0.048 discriminant
#    0.048 robot
#    0.047 particle
#    0.047 gradient
#    0.046 boltzmann
#    0.046 nets
#    0.046 vlsi
#    0.045 allen
#    0.045 coalitional
#    0.045 sparsity
#    0.044 bayes
#    0.043 sat
#    0.043 td
#    0.043 defeasible
#    0.043 stimulus
#    0.042 manifold
#    0.042 laplacian
#    0.042 roc
#    0.041 finite
#    0.041 eeg
#    0.041 logistic
#    0.041 argumentation
#    0.041 backgammon
#    0.041 bci
#    0.041 indivisible
#    0.040 hamiltonian
#    0.040 neuromorphic
#    0.040 possibilistic
#    0.040 prolog
#    0.039 bounds
#    0.039 recurrent
#    0.039 auditory
#    0.039 perceptrons
#    0.038 manifolds
#    0.038 rbf
#    0.037 connectionist
#    0.037 pca
#    0.037 deconvolution
#    0.037 thompson
#    0.037 speaker
#    0.036 horn
#    0.036 coalition
#    0.036 critic
#    0.036 dec
#    0.036 dueling
#    0.036 neocognitron
#    0.036 synapse
#    0.036 regret
#    0.036 dimensionality
#    0.035 arc
#    0.035 texture
#    0.035 reward
#    0.035 mri
#    0.035 semidefinite
#    0.034 gaussians
#    0.034 inhibition
#    0.034 margins
#    0.034 nash
#    0.034 beliefs
#    0.034 planner
#    0.034 robots
#    0.033 auctions
#    0.033 imitation
#    0.033 observable
#    0.033 robotics
#    0.033 posterior
#    0.033 stereo
#    0.033 perceptron
#    0.033 artificial
#    0.032 margin
#    0.032 calculus
#    0.032 entailment
#    0.032 abductive
#    0.032 actor
#    0.032 bethe
#    0.032 exponentiated
#    0.032 hyperparameters
#    0.032 introspective
#    0.032 ltl
#    0.032 normative
#    0.032 resting
#    0.032 semantical
#    0.032 univariate
#    0.032 newton
#    0.031 ebl
#    0.031 slam
#    0.031 motion
#    0.030 symmetry
#    0.030 fmri
#    0.030 penalty
#    0.030 default
#    0.030 polynomial
#    0.030 squares
# DM
#    0.367 itemsets
#    0.323 kdd
#    0.206 cup
#    0.119 nonnegative
#    0.105 microarray
#    0.101 climate
#    0.084 marketing
#    0.079 biclustering
#    0.068 discretization
#    0.066 olap
#    0.065 wsdm
#    0.064 itemset
#    0.063 peculiarity
#    0.063 imbalanced
#    0.062 clusterings
#    0.062 logistic
#    0.061 discriminant
#    0.059 kernels
#    0.059 lasso
#    0.058 customers
#    0.058 dimensionality
#    0.055 subspace
#    0.055 imbalance
#    0.054 bayes
#    0.053 discord
#    0.053 shapelets
#    0.053 squashing
#    0.053 motifs
#    0.052 regularization
#    0.051 miner
#    0.051 roc
#    0.051 pathways
#    0.049 warping
#    0.048 differentially
#    0.048 drifting
#    0.048 projected
#    0.047 regularized
#    0.047 episodes
#    0.047 anomalous
#    0.047 covariance
#    0.044 sentiment
#    0.043 yeast
#    0.043 metabolic
#    0.043 outbreak
#    0.042 patent
#    0.042 2017
#    0.042 bicluster
#    0.042 blanket
#    0.042 boilers
#    0.042 intelligible
#    0.042 precursors
#    0.042 readmission
#    0.042 untrustworthy
#    0.042 webkdd
#    0.041 fraud
#    0.041 rough
#    0.041 publishing
#    0.041 interpretable
#    0.040 protein
#    0.040 outliers
#    0.040 recommender
#    0.037 sales
#    0.037 anonymization
#    0.037 customer
#    0.037 churn
#    0.037 subsequences
#    0.036 reviews
#    0.036 redescriptions
#    0.036 mml
#    0.036 weka
#    0.036 twitter
#    0.035 analytics
#    0.034 transactional
#    0.034 subgraphs
#    0.033 purchase
#    0.033 interestingness
#    0.032 estate
#    0.032 censored
#    0.032 cfb
#    0.032 cprod1
#    0.032 derivable
#    0.032 drought
#    0.032 embers
#    0.032 geoscientific
#    0.032 hyperclique
#    0.032 jackets
#    0.032 knime
#    0.032 pharmacovigilance
#    0.032 underrepresented
#    0.032 unexpectedness
#    0.031 unlabeled
#    0.031 wikipedia
#    0.031 bid
#    0.031 television
#    0.031 genes
#    0.031 laplacian
#    0.031 lung
#    0.031 ordinal
#    0.031 sparsity
#    0.031 transductive
#    0.031 arbitrarily
#    0.031 agglomerative
#    0.031 bagging
#    0.029 sensor
#    0.029 enterprise
#    0.029 poisson
#    0.029 named
#    0.029 manifold
#    0.029 uplift
#    0.029 biomarker
#    0.029 coevolving
#    0.029 pathological
#    0.029 precipitation
#    0.029 prognosis
#    0.029 spacecraft
#    0.029 commute
#    0.029 microaggregation
#    0.029 phenotyping
#    0.029 rna
#    0.029 sell
#    0.028 ensembles
#    0.028 mapreduce
#    0.028 svms
#    0.028 correlations
#    0.027 randomization
#    0.027 bregman
#    0.027 proteins
#    0.027 subgroup
#    0.027 ticket
#    0.027 nearest
#    0.027 citation
#    0.026 enumerating
#    0.026 ga
#    0.026 hyperspectral
#    0.026 orange
#    0.026 subtrees
#    0.026 categorical
#    0.026 discriminative
#    0.025 adverse
#    0.025 basket
#    0.025 colony
#    0.025 substructures
#    0.025 unexpected
#    0.025 malware
#    0.025 forests
#    0.025 interesting
#    0.025 neighbor
#    0.025 svm
#    0.024 diffusion
#    0.024 maximization
# IR
#    0.404 sigir
#    0.185 recsys
#    0.162 assessor
#    0.159 recommender
#    0.154 trec
#    0.134 ntcir
#    0.127 esair
#    0.124 passage
#    0.124 patent
#    0.107 enterprise
#    0.104 ecir
#    0.095 wikipedia
#    0.087 inex
#    0.082 xml
#    0.081 diversification
#    0.077 federated
#    0.075 metasearch
#    0.069 organisational
#    0.069 bm25
#    0.064 stemming
#    0.064 organisations
#    0.064 acm
#    0.063 retrievability
#    0.061 recommending
#    0.060 searcher
#    0.058 km
#    0.058 eine
#    0.058 tipster
#    0.058 verbose
#    0.057 multilingual
#    0.055 olap
#    0.053 caching
#    0.052 personalize
#    0.051 collections
#    0.051 pagerank
#    0.049 rdf
#    0.047 subtopic
#    0.047 2016
#    0.046 sentiment
#    0.046 thesaurus
#    0.046 xpath
#    0.046 blend
#    0.046 booksonline
#    0.046 cikm
#    0.046 ein
#    0.046 malaysia
#    0.046 smes
#    0.046 tdt
#    0.045 indexes
#    0.045 named
#    0.044 suggestion
#    0.043 assessments
#    0.043 suggestions
#    0.043 capital
#    0.043 clir
#    0.043 monolingual
#    0.041 twitter
#    0.040 twig
#    0.040 transliteration
#    0.040 tacit
#    0.040 personalised
#    0.040 judgments
#    0.040 reviews
#    0.040 dolap
#    0.038 articles
#    0.037 clickthrough
#    0.036 files
#    0.036 poster
#    0.035 versioned
#    0.035 bibliometric
#    0.035 ecommerce
#    0.035 multidatabase
#    0.035 stemmer
#    0.035 warehousing
#    0.035 aboutness
#    0.035 cite
#    0.035 dtmbio
#    0.035 gamifir
#    0.035 ineffectiveness
#    0.035 jordanian
#    0.035 malaysian
#    0.035 prerequisites
#    0.035 rocchio
#    0.035 simfusion
#    0.035 und
#    0.035 zur
#    0.034 answers
#    0.034 citation
#    0.034 corpora
#    0.034 2014
#    0.034 factoid
#    0.034 plagiarism
#    0.034 recommenders
#    0.034 bibliographic
#    0.034 joins
#    0.034 posts
#    0.033 engines
#    0.033 opinion
#    0.033 tweets
#    0.032 spoken
#    0.032 fifth
#    0.032 seventh
#    0.032 lifelog
#    0.032 oodb
#    0.032 phrasal
#    0.032 retrieve
#    0.032 tokenization
#    0.031 graded
#    0.031 12
#    0.030 folksonomy
#    0.030 hyperlink
#    0.030 intellectual
#    0.030 reranking
#    0.030 plsa
#    0.030 passages
#    0.029 english
#    0.029 reformulation
#    0.029 tweet
#    0.029 ria
#    0.029 searchers
#    0.029 definitional
#    0.029 posting
#    0.029 disks
#    0.029 tf
#    0.028 keyphrase
#    0.028 logistic
#    0.028 file
#    0.028 literature
#    0.028 arabic
#    0.028 sql
#    0.028 pooling
#    0.027 weighting
#    0.026 duplicate
#    0.026 faceted
#    0.026 contextualization
#    0.026 european
#    0.026 recommend
#    0.026 skyline
#    0.026 14
#    0.026 2003
#    0.026 itemsets
#    0.026 barriers
#    0.026 ephemeral
#    0.025 rating
#    0.025 service
#    0.025 hypertext
#    0.025 affecting
#    0.025 bandits
#    0.025 dbms
#    0.025 math
# DB
#    0.284 joins
#    0.224 sql
#    0.224 xquery
#    0.218 xpath
#    0.190 olap
#    0.184 dbms
#    0.183 xml
#    0.176 db2
#    0.145 oltp
#    0.135 concurrency
#    0.129 warehousing
#    0.122 materialized
#    0.104 rdf
#    0.102 skyline
#    0.093 join
#    0.090 transaction
#    0.084 workloads
#    0.081 multidatabase
#    0.081 warehouse
#    0.078 declustering
#    0.078 hana
#    0.078 serializability
#    0.077 schema
#    0.076 rdbms
#    0.075 mapreduce
#    0.074 caching
#    0.073 synopses
#    0.070 optimizer
#    0.063 main
#    0.061 twig
#    0.061 sigmod
#    0.061 dbmss
#    0.060 sparql
#    0.059 locking
#    0.059 replication
#    0.059 multiversion
#    0.058 semistructured
#    0.057 transactions
#    0.056 sap
#    0.056 serializable
#    0.056 provenance
#    0.053 reorganization
#    0.052 transactional
#    0.051 logging
#    0.050 aqualogic
#    0.050 oodb
#    0.049 hadoop
#    0.049 analytics
#    0.048 tuples
#    0.048 disks
#    0.048 skylines
#    0.047 enterprise
#    0.046 differentially
#    0.046 tpc
#    0.045 subscribe
#    0.045 postgresql
#    0.045 tertiary
#    0.044 datalog
#    0.044 file
#    0.043 rewriting
#    0.043 warehouses
#    0.043 multiprocessor
#    0.043 deductive
#    0.042 cube
#    0.042 dataspaces
#    0.042 cpus
#    0.042 optimizers
#    0.041 schemas
#    0.039 containment
#    0.039 lineage
#    0.039 publishing
#    0.039 itemsets
#    0.039 codasyl
#    0.039 indexes
#    0.039 service
#    0.039 federated
#    0.039 commit
#    0.038 nearest
#    0.037 nosql
#    0.037 simrank
#    0.037 selectivity
#    0.036 integrity
#    0.036 files
#    0.036 answers
#    0.035 p2p
#    0.035 etl
#    0.035 parallelism
#    0.034 chase
#    0.034 imprecise
#    0.034 reachability
#    0.034 clio
#    0.034 columnar
#    0.034 costing
#    0.034 extendible
#    0.034 ldap
#    0.034 monetdb
#    0.034 multicores
#    0.034 nonrecursive
#    0.034 pig
#    0.034 vldb
#    0.033 replicated
#    0.033 workload
#    0.033 neighbor
#    0.033 sensor
#    0.032 db
#    0.031 conscious
#    0.031 buffer
#    0.031 advisor
#    0.031 publish
#    0.031 rfid
#    0.031 workflows
#    0.031 executions
#    0.031 teradata
#    0.031 aries
#    0.031 starburst
#    0.030 middleware
#    0.029 resident
#    0.029 tenant
#    0.029 contention
#    0.029 trie
#    0.028 managing
#    0.028 flash
#    0.028 aggregations
#    0.028 ssd
#    0.028 11g
#    0.028 codd
#    0.028 dataflows
#    0.028 dtd
#    0.028 jim
#    0.028 nail
#    0.028 numa
#    0.028 oracle8i
#    0.027 bulk
#    0.027 duplicates
#    0.027 outsourced
#    0.027 predicate
#    0.027 knn
#    0.027 quantiles
#    0.027 atomicity
#    0.027 ssds
#    0.027 vertica
#    0.027 postgres
#    0.027 authenticated
#    0.027 quorum
#    0.027 radix
#    0.027 moving
#    0.026 scientific
#    0.026 write
#    0.026 anonymization
#    0.026 languages
# HI
#    0.255 tangible
#    0.240 tabletop
#    0.187 cscw
#    0.160 hci
#    0.149 pointing
#    0.138 tactile
#    0.124 handed
#    0.116 intera
#    0.109 da
#    0.105 uma
#    0.105 usu
#    0.104 keyboard
#    0.100 tabletops
#    0.096 touchscreen
#    0.095 screen
#    0.095 haptic
#    0.090 groupware
#    0.089 um
#    0.086 avalia
#    0.078 rios
#    0.078 ux
#    0.076 estudo
#    0.074 fabrication
#    0.073 sistemas
#    0.073 usabilidade
#    0.073 finger
#    0.072 menus
#    0.070 designers
#    0.070 keyboards
#    0.070 para
#    0.069 adults
#    0.069 es
#    0.062 sobre
#    0.061 telepresence
#    0.059 mounted
#    0.057 mediated
#    0.057 wearable
#    0.057 novice
#    0.057 aplica
#    0.057 appropriation
#    0.057 smartwatches
#    0.057 ui
#    0.056 workplace
#    0.055 multitasking
#    0.055 personas
#    0.054 gesture
#    0.054 vibrotactile
#    0.054 women
#    0.054 embodied
#    0.054 parents
#    0.054 fitts
#    0.053 gaze
#    0.052 entertainment
#    0.052 affordances
#    0.051 widgets
#    0.051 scaffolding
#    0.051 stylus
#    0.051 veis
#    0.051 auditory
#    0.050 everyday
#    0.049 pen
#    0.049 handheld
#    0.049 older
#    0.049 civic
#    0.049 goms
#    0.049 ideation
#    0.049 lise
#    0.049 tangibles
#    0.048 warnings
#    0.046 bimanual
#    0.046 empathy
#    0.046 homeless
#    0.046 ihc
#    0.046 tica
#    0.046 creative
#    0.045 practices
#    0.044 haptics
#    0.043 caregivers
#    0.043 ncia
#    0.043 toys
#    0.043 sickness
#    0.043 promote
#    0.042 gestures
#    0.042 emotional
#    0.042 sensemaking
#    0.042 posture
#    0.041 multitouch
#    0.041 ethnography
#    0.041 vr
#    0.041 touchscreens
#    0.041 uso
#    0.040 cues
#    0.040 usability
#    0.039 distraction
#    0.039 menu
#    0.039 gameplay
#    0.038 physical
#    0.038 anxiety
#    0.038 caso
#    0.038 exertion
#    0.038 involvement
#    0.038 leisure
#    0.038 projector
#    0.038 sigchi
#    0.038 teens
#    0.037 visualizations
#    0.037 tablets
#    0.037 brainstorming
#    0.037 collocated
#    0.037 dos
#    0.037 smartwatch
#    0.037 stereoscopic
#    0.036 reality
#    0.036 persuasive
#    0.036 workspace
#    0.035 immersion
#    0.035 interruption
#    0.035 buttons
#    0.035 como
#    0.035 desafios
#    0.035 feeling
#    0.035 hover
#    0.035 interruptibility
#    0.035 tutorials
#    0.035 sig
#    0.035 gaming
#    0.034 body
#    0.034 assistive
#    0.034 rehabilitation
#    0.034 surfaces
#    0.034 programmers
#    0.033 craft
#    0.033 storytelling
#    0.033 engaging
#    0.032 inform
#    0.032 activism
#    0.032 capacitive
#    0.032 ecologies
#    0.032 fabricating
#    0.032 infrastructuring
#    0.032 unobtrusive
#    0.032 messaging
#    0.032 material
#    0.031 embodiment
#    0.031 encourage
#    0.031 enterprise
#    0.031 workspaces
#    0.031 avatar
#    0.031 stroke
#    0.030 meetings
# NLP
#    0.260 semeval
#    0.232 treebank
#    0.198 ccg
#    0.194 adjoining
#    0.185 morphological
#    0.177 parser
#    0.154 smt
#    0.142 verb
#    0.135 bilingual
#    0.133 selectional
#    0.120 discourse
#    0.119 entailment
#    0.116 transliteration
#    0.113 english
#    0.112 pos
#    0.112 categorial
#    0.107 coreference
#    0.106 parse
#    0.104 paraphrase
#    0.098 dialogue
#    0.096 paraphrases
#    0.093 corpora
#    0.092 noun
#    0.091 hpsg
#    0.091 wsd
#    0.087 parsers
#    0.086 anaphora
#    0.084 lfg
#    0.083 phrasal
#    0.083 monolingual
#    0.080 ellipsis
#    0.080 penn
#    0.079 spoken
#    0.077 named
#    0.075 multilingual
#    0.074 multiword
#    0.072 lexicalized
#    0.072 morphology
#    0.071 mt
#    0.068 acl2
#    0.068 literary
#    0.068 natural
#    0.068 preposition
#    0.067 nlp
#    0.067 distributional
#    0.066 chunking
#    0.066 constituent
#    0.066 german
#    0.065 morphologically
#    0.065 sentiment
#    0.065 pcfg
#    0.063 pronoun
#    0.062 syntactic
#    0.061 pronominal
#    0.059 corpus
#    0.058 phrase
#    0.057 referring
#    0.057 esl
#    0.057 treebanks
#    0.055 combinatory
#    0.053 polysemy
#    0.053 underspecified
#    0.053 wmt
#    0.053 grammars
#    0.053 arabic
#    0.051 linguistically
#    0.050 paraphrasing
#    0.050 reordering
#    0.049 sentence
#    0.049 subcategorization
#    0.049 decipherment
#    0.049 hebrew
#    0.049 morpheme
#    0.048 tagger
#    0.047 french
#    0.047 linguistic
#    0.046 verbs
#    0.046 tempeval
#    0.045 transducers
#    0.045 finite
#    0.045 korean
#    0.045 spanish
#    0.044 formalisms
#    0.044 taggers
#    0.043 comparable
#    0.042 hindi
#    0.042 framenet
#    0.042 pronunciation
#    0.042 figurative
#    0.042 hardbound
#    0.042 lambek
#    0.042 pronouns
#    0.042 morpho
#    0.042 urdu
#    0.040 phoneme
#    0.040 tense
#    0.040 dialogues
#    0.039 prosodic
#    0.039 prepositional
#    0.038 czech
#    0.038 essays
#    0.038 metonymy
#    0.038 centering
#    0.038 nouns
#    0.037 2016
#    0.037 languages
#    0.036 wordnet
#    0.036 connectives
#    0.036 linguistics
#    0.034 decoding
#    0.034 phonological
#    0.034 basque
#    0.034 determiner
#    0.034 srl
#    0.034 unlexicalized
#    0.034 japanese
#    0.034 phonology
#    0.034 subjectivity
#    0.034 extractive
#    0.033 chart
#    0.032 portuguese
#    0.032 isbn
#    0.032 compounds
#    0.032 sentential
#    0.031 bigrams
#    0.031 hypernym
#    0.031 inflectional
#    0.031 tokenization
#    0.031 utterances
#    0.030 wikipedia
#    0.030 agglutinative
#    0.030 amr
#    0.030 anaphoricity
#    0.030 fbk
#    0.030 idiom
#    0.030 ie
#    0.030 inflected
#    0.030 parses
#    0.030 propbank
#    0.030 translations
#    0.030 lexicon
#    0.030 textual
#    0.029 reranking
#    0.029 pp
#    0.029 verbal
#    0.029 grammatical
#    0.029 lexicons
#    0.029 grammaticality
#    0.029 pcfgs
#    0.028 collocations
# CV
#    0.400 stereo
#    0.284 photometric
#    0.229 pose
#    0.200 deformable
#    0.156 appearance
#    0.156 monocular
#    0.155 texture
#    0.155 registration
#    0.154 occlusion
#    0.153 articulated
#    0.152 shading
#    0.145 rigid
#    0.144 motion
#    0.121 deblurring
#    0.120 illumination
#    0.115 cameras
#    0.099 contours
#    0.097 rgb
#    0.094 matting
#    0.092 occlusions
#    0.091 uncalibrated
#    0.090 surfaces
#    0.088 affine
#    0.087 saliency
#    0.084 specular
#    0.082 reflectance
#    0.077 epipolar
#    0.076 manifolds
#    0.075 catadioptric
#    0.075 panoramic
#    0.074 facial
#    0.074 subtraction
#    0.073 scenes
#    0.071 priors
#    0.068 camera
#    0.066 nonrigid
#    0.065 projector
#    0.065 rgbd
#    0.063 defocus
#    0.063 curvature
#    0.063 volumetric
#    0.063 lighting
#    0.057 cluttered
#    0.056 riemannian
#    0.056 correspondences
#    0.055 deformation
#    0.055 silhouette
#    0.054 illuminant
#    0.054 crowded
#    0.052 slam
#    0.052 scene
#    0.051 blur
#    0.051 patch
#    0.049 curved
#    0.049 textures
#    0.049 morphable
#    0.049 mosaics
#    0.047 hough
#    0.046 cuts
#    0.045 symmetry
#    0.043 surface
#    0.043 rectification
#    0.043 cosegmentation
#    0.043 mosaicing
#    0.041 shutter
#    0.041 geodesic
#    0.041 cnn
#    0.041 omnidirectional
#    0.040 constancy
#    0.040 refractive
#    0.040 superpixels
#    0.039 contour
#    0.039 foreground
#    0.038 variational
#    0.038 detectors
#    0.037 hyperspectral
#    0.037 deconvolution
#    0.037 snakes
#    0.037 invariant
#    0.036 manifold
#    0.036 faces
#    0.036 cues
#    0.036 projective
#    0.035 cue
#    0.035 aperture
#    0.035 mrfs
#    0.035 occluded
#    0.035 body
#    0.035 calibration
#    0.034 patches
#    0.034 mumford
#    0.034 shah
#    0.033 aerial
#    0.033 imagery
#    0.032 mri
#    0.032 shadows
#    0.032 egomotion
#    0.032 inpainting
#    0.032 occluding
#    0.032 stereoscopic
#    0.032 planar
#    0.031 discriminant
#    0.031 gait
#    0.031 albedo
#    0.031 autocalibration
#    0.031 curvilinear
#    0.031 surveillance
#    0.031 pde
#    0.031 lidar
#    0.030 binocular
#    0.030 multispectral
#    0.030 textured
#    0.030 covariance
#    0.029 radiometric
#    0.029 homography
#    0.029 trifocal
#    0.028 motions
#    0.028 shadow
#    0.028 shapes
#    0.028 brdf
#    0.028 cortical
#    0.028 lambertian
#    0.028 stereopsis
#    0.027 infrared
#    0.027 discriminative
#    0.027 apparent
#    0.027 keypoint
#    0.027 medial
#    0.027 sfm
#    0.027 restoration
#    0.026 diffeomorphic
#    0.026 blurred
#    0.026 optic
#    0.025 weakly
#    0.025 denoising
#    0.025 deformations
#    0.025 gabor
#    0.025 silhouettes
#    0.025 minutiae
#    0.025 spacetime
#    0.025 subdivision
#    0.025 energies
#    0.025 hallucination
#    0.025 ransac
#    0.024 multiscale
#    0.024 convolutional
#    0.024 invariance
#    0.024 laplacian
#    0.023 crfs
#    0.023 parallax
# COM
#    0.456 802
#    0.311 packet
#    0.290 multicast
#    0.289 wdm
#    0.234 tcp
#    0.215 atm
#    0.163 lans
#    0.135 wavelength
#    0.119 multihop
#    0.108 csma
#    0.098 sdn
#    0.096 wlans
#    0.096 qos
#    0.094 routing
#    0.086 queueing
#    0.085 routers
#    0.082 cdma
#    0.078 bgp
#    0.077 openflow
#    0.076 sensor
#    0.072 lan
#    0.071 switches
#    0.070 slotted
#    0.070 vbr
#    0.069 11
#    0.067 antennas
#    0.067 dqdb
#    0.067 hop
#    0.064 tdma
#    0.062 isdn
#    0.062 ofdma
#    0.060 wifi
#    0.060 lightwave
#    0.060 lte
#    0.059 bandwidth
#    0.059 radio
#    0.057 ipv6
#    0.056 protocol
#    0.056 diffserv
#    0.056 wimax
#    0.055 handoff
#    0.055 handover
#    0.054 abr
#    0.054 downlink
#    0.051 congestion
#    0.051 forwarding
#    0.051 queued
#    0.050 wlan
#    0.050 broadband
#    0.049 buffered
#    0.049 ieee
#    0.049 scheduling
#    0.047 arq
#    0.047 admission
#    0.046 mimo
#    0.046 router
#    0.044 carrier
#    0.044 mpls
#    0.043 reservation
#    0.042 aloha
#    0.042 uplink
#    0.042 switch
#    0.041 service
#    0.041 aqm
#    0.041 cellular
#    0.040 multicasting
#    0.040 delay
#    0.039 wsns
#    0.039 interference
#    0.039 manets
#    0.039 energy
#    0.038 offloading
#    0.038 dtn
#    0.037 survivable
#    0.037 datacenter
#    0.037 flooding
#    0.036 arrivals
#    0.036 retransmission
#    0.036 umts
#    0.035 caching
#    0.034 fddi
#    0.034 transmissions
#    0.034 vehicular
#    0.034 ethernet
#    0.033 opportunistic
#    0.033 priority
#    0.032 relay
#    0.032 queue
#    0.031 multipath
#    0.031 hosts
#    0.031 routed
#    0.030 fading
#    0.030 ofdm
#    0.030 schedulers
#    0.029 11e
#    0.029 backhaul
#    0.029 banyan
#    0.029 multihoming
#    0.029 vanets
#    0.028 bittorrent
#    0.028 duty
#    0.028 deflection
#    0.028 dimensioning
#    0.028 multirate
#    0.028 osi
#    0.028 protocols
#    0.027 fair
#    0.027 ip
#    0.027 sip
#    0.027 underwater
#    0.026 rfid
#    0.026 femtocell
#    0.026 relaying
#    0.026 rerouting
#    0.026 backbone
#    0.026 queues
#    0.026 provisioning
#    0.025 fi
#    0.025 metropolitan
#    0.025 qoe
#    0.025 poster
#    0.025 unicast
#    0.025 buffers
#    0.025 d2d
#    0.025 multiplexer
#    0.025 ospf
#    0.025 stateless
#    0.025 transmit
#    0.024 duplex
#    0.024 rings
#    0.024 fairness
#    0.024 multiplexing
#    0.023 pcs
#    0.023 3g
#    0.023 grooming
#    0.023 internetworking
#    0.023 mans
#    0.023 middlebox
#    0.023 sinr
#    0.023 sybil
#    0.023 zigbee
#    0.023 switched
#    0.022 buffer
#    0.022 telephony
#    0.022 receiver
#    0.021 bus
#    0.021 cell
#    0.021 5g
#    0.021 anycast
#    0.021 erasure

# %%
#for paper_id, meta in paper.items():
#    if 'sigir' in str.lower(meta['title']):
#        print(meta['title'])

# %%
#key_ = ["WWW_keyword", "WWW_score", "ML_keyword", "ML_score", "DM_keyword", "DM_score", "IR_keyword", "IR_score", "DB_keyword", "DB_score", "HI_keyword", "HI_score", "NLP_keyword", "NLP_score", "CV_keyword", "CV_score", "COM_keyword", "COM_score", "OS_keyword", "OS_score"]
key_ = ["WWW_keyword", "WWW_score", "ML_keyword", "ML_score", "DM_keyword", "DM_score", "IR_keyword", "IR_score", "DB_keyword", "DB_score", "HI_keyword", "HI_score", "NLP_keyword", "NLP_score", "CV_keyword", "CV_score", "COM_keyword", "COM_score"]
val_ = []
for idx in range(n_clusters):
    val_.append([keyword for keyword, score in keyword_tfidf_cluster_list[idx].items()])
    val_.append([score for keyword, score in keyword_tfidf_cluster_list[idx].items()])
dic = {key_[i] : val_[i] for i in range(len(key_))}
df = pd.DataFrame(dic)
df.to_csv("field_tfidf.csv")
df.head()
# Out:
#   WWW_keyword  WWW_score   ML_keyword  ML_score   DM_keyword  DM_score  \
# 0         rdf   0.493595      spiking  0.322661     itemsets  0.367078
# 1         owl   0.383495      neurons  0.251303          kdd  0.322716
# 2      sparql   0.341404         mdps  0.170638          cup  0.206327
# 3     restful   0.119673   plasticity  0.149565  nonnegative  0.118882
# 4     service   0.116207  variational  0.128800   microarray  0.104729
#
#     IR_keyword  IR_score DB_keyword  DB_score HI_keyword  HI_score  \
# 0        sigir  0.404481      joins  0.284148   tangible  0.255272
# 1       recsys  0.184906        sql  0.223864   tabletop  0.240414
# 2     assessor  0.161792     xquery  0.223618       cscw  0.186762
# 3  recommender  0.158591      xpath  0.218027        hci  0.159514
# 4         trec  0.153547       olap  0.189820   pointing  0.148571
#
#      NLP_keyword  NLP_score   CV_keyword  CV_score COM_keyword  COM_score
# 0        semeval   0.260087       stereo  0.399848         802   0.455968
# 1       treebank   0.231767  photometric  0.284169      packet   0.310632
# 2            ccg   0.197572         pose  0.228750   multicast   0.289521
# 3      adjoining   0.193773   deformable  0.199847         wdm   0.289270
# 4  morphological   0.185099   appearance  0.155629         tcp   0.234030

# %%
#用いるキーワード数
n_used_keyword = 50
field_used_keyword = {}

field_attribute = np.zeros((len(field_list), 300))
for field in range(n_clusters):
    vector = np.zeros((300))
    n_word = 0
    #weight = n_used_keyword
    weight = 0
    used_keyword = []
    for word in val_[field * 2]:
        try:
            #vector = vector + weight * word2vec[word]
            w = keyword_tfidf_cluster_list[field][word]
            vector = vector + w * word2vec[word]
            n_word += 1
            #weight -= 1
            weight += w
            used_keyword.append(word)
            #print(word)
        except KeyError as error:
            pass
            #print(word)
        if n_word == n_used_keyword:
            break
    if n_word == 0 or n_word < n_used_keyword:
        print("あり得ない")
        field_attribute[field] = vector
    else:
        #field_attribute[field] = vector / sum(i for i in range(1, n_used_keyword+1))
        field_attribute[field] = vector / weight
    field_used_keyword[field_list[field]] = used_keyword

# %%
df = pd.DataFrame(field_used_keyword)
df.to_csv("used_word.csv")

# %%
print(field_attribute.shape)
print(node_attribute.shape)
# Out:
# (9, 300)
# (127980, 300)

# %%
import sklearn
node_attribute_similar2field = sklearn.metrics.pairwise.cosine_similarity(node_attribute, field_attribute)
node_attribute_similar2field.shape
# Out:
# (127980, 9)

# %%
# 低次元に写像しクラスタを可視化
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
node_attribute_pca = pca.fit_transform(node_attribute_similar2field)
print(node_attribute_pca.shape)
# Out:
# (127980, 2)

# %%
x_field = [[] for _ in range(n_clusters)]
y_field = [[] for _ in range(n_clusters)]
for paper_id, meta in paper.items():
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    i = field_list.index(field)
    x_field[i].append(node_attribute_pca[node_idx_table[paper_id]][0])
    y_field[i].append(node_attribute_pca[node_idx_table[paper_id]][1])

# %%
import matplotlib.colors as mcolors
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
colors = [val for key, val in mcolors.TABLEAU_COLORS.items()]

for i in range(n_clusters):
    ax.scatter(x_field[i], y_field[i], c=colors[i], label=field_list[i])

ax.legend()
fig.savefig('scatter_sim2refvec.pdf')

# %%
# 低次元に写像しクラスタを可視化
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
field_attribute_pca = pca.fit_transform(field_attribute)
print(field_attribute_pca.shape)
# Out:
# (9, 2)

# %%
import matplotlib.colors as mcolors
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
colors = [val for key, val in mcolors.TABLEAU_COLORS.items()]

for i in range(n_clusters):
    ax.scatter(field_attribute_pca[i][0], field_attribute_pca[i][1], c=colors[i], label=field_list[i])
    plt.annotate(field_list[i], xy=(field_attribute_pca[i][0]-0.03, field_attribute_pca[i][1]+0.03))

fig.savefig('scatter_field.pdf')

# %%
# ここで実際の分野とタイトルのそれらしさの一致率をチェック
for paper_id, meta in sorted(paper.items())[:10]:
    field = [f for f, vl in field_venue_dic.items() if meta['venue'] in vl][0]
    print(field, field_list[node_attribute_similar2field[node_idx_table[paper_id]].argmax()])
    print(meta['title'])
# Out:
# HI DM
# How dangerous is looking away from the road? Algorithms predict crash risk from glance patterns in naturalistic driving.
# ML CV
# Constructing Prioritized Fuzzy Models
# WEB DM
# Understanding toxic behavior in online games
# IR DB
# Operational requirements for scalable search systems
# HI HI
# Designing mobile phone interface with children
# NLP HI
# Training Tree Transducers.
# IR DM
# Exploring group mobility for replica data allocation in a mobile environment
# NLP WEB
# A Logic-Based Semantic Approach to Recognizing Textual Entailment
# IR IR
# Using Key Concepts in a Translation Model for Retrieval
# COM DM
# A study of LBS accuracy in the UK and a novel approach to inferring the positioning technology employed

# %%
node_attribute_similar2field
# Out:
# array([[0.33046923, 0.23419443, 0.29922613, ..., 0.28316364, 0.37852446,
#         0.26872912],
#        [0.44808785, 0.28672234, 0.44097759, ..., 0.38652292, 0.30709105,
#         0.39912026],
#        [0.41590473, 0.37008611, 0.45156255, ..., 0.44620744, 0.53161413,
#         0.2403609 ],
#        ...,
#        [0.45566103, 0.37731486, 0.49324944, ..., 0.3594769 , 0.37085895,
#         0.43181795],
#        [0.29168873, 0.24889184, 0.30903067, ..., 0.268031  , 0.27329848,
#         0.21843677],
#        [0.41259992, 0.36935613, 0.42293449, ..., 0.26655503, 0.31810098,
#         0.3821432 ]])

# %%
rows = []
for idx, ts in enumerate(years):
    rows.append([ts, idx])
df = pd.DataFrame(rows, columns=['TS', 'ID'])
df.to_csv(outputDir + '/ts_idx.csv', index=False, encoding='utf_8_sig')

# %%
df = pd.read_csv(outputDir + '/ts_idx.csv')
df_TS = df.TS.values
df_ID = df.ID.values
ts_idx_table = {}
for row in range(df.shape[0]):
    ts_idx_table[df_TS[row]] = df_ID[row]

# %%
exist_table = np.zeros((len(node_idx_table), len(ts_idx_table)))
for year in years:
    for paper_id, meta in paper.items():
        if year < meta['year']:
            exist_table[node_idx_table[paper_id]][ts_idx_table[year]] = 0
        else:
            exist_table[node_idx_table[paper_id]][ts_idx_table[year]] = 1

np.save(outputDir + '/exist_table', exist_table)

# %%
for year in years:
    node_attribute = np.zeros((len(node_idx_table), len(field_list)))
    index = exist_table[:, ts_idx_table[year]] == 1
    node_attribute[index] = node_attribute_similar2field[index]
    np.save(outputDir + '/node_attribute' + str(ts_idx_table[year]), node_attribute)

# %%
for year in years:
    adjacency = lil_matrix((len(node_idx_table), len(node_idx_table)))
    for paper_id, meta in paper.items():
        if year < meta['year']:
            continue
        for reference_id in meta['references']:
            if not reference_id in node_idx_table.keys():
                continue
            adjacency[node_idx_table[paper_id], node_idx_table[reference_id]] = 1
    mmwrite(outputDir + '/adjacency' + str(ts_idx_table[year]), adjacency)

# %%
exist_table.shape
# Out:
# (127980, 50)

# %%
exist_table[:, -1] == 1
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
node_attribute_similar2field.shape
# Out:
# (127980, 9)

# %%
len(field_list)
# Out:
# 9

# %%
# 従来の問題点1 : connected component は1だが、必ずしもnew nodeのreference先が存在するとは限らない
# 従来の問題点2 : 今回はnew node予測のみなので必ずしもexisting node の隣接行列等は必要ない
# 従来の問題点3 : サイズが大きすぎてdeep learningができない
# 従来の問題点4 : 属性のその他が多すぎる問題

# 方針1 : new nodeがreference先を1つ以上持つものをサンプリングする
# 方針2 : original (2118551)のグラフが持つ属性の割合を保持する (e.g. 1990年はdb:0.8, ml:0.2、1990年はdb:0.6, ml:0.4、・・・) ようにnew nodeをサンプリングする
# 方針3 : 方針1と方針2を満たすnew nodeとそのreference先のセットを1サンプルとする

# 方針3で作成されたグラフを時系列に組み合わせて新たな時系列グラフを作り直す。
# ただし、各サンプル（各タイムステップ）のexisting node（reference先のノード）はそのタイミングのみ存在するものとする。
# 次のタイミングでは過去のnew nodeもexisting nodeも消失ノードとする（new node 予測のみなので、消失予測は関係無い）
# new node & existing nodeが新たに出現し、すぐさま消失するイメージ
# new nodeの出現数もoriginalの等縮小倍率とする
#（本当は過去ノードは消失ノード扱いのため存在していないが）グラフとしてはサブサンプルされたnew node & existing nodeの累積個数とする。
# この方法で作成すれば一応、new nodeの数と属性の統計量を保持したままグラフを削れる

# → まずはグラフサイズを削る前に年ごとの属性の割合を明らかにする

# %%
# 年ごとのpaper_id の辞書を作成
year_paper_dic = {}
for year in years:
    year_paper_dic[year] = []
for paper_id, meta in paper.items():
    year_paper_dic[meta['year']].append(paper_id)

# 年ごとのnew nodeの数を表示
for year in years:
    print(year, len(year_paper_dic[year]))

# %%
node_attribute = np.zeros((len(node_idx_table), 300))
for paper_id, meta in paper.items():
    vector = np.zeros((300))
    #print(meta['title'])
    n_word = 0
    for word in meta['title'].split(' '):
        try:
            vector = vector + word2vec[word]
            n_word += 1
            #print(word)
        except KeyError as error:
            pass
            #print(error)
    if n_word == 0:
        node_attribute[node_idx_table[paper_id]] = vector
    else:
        node_attribute[node_idx_table[paper_id]] = vector / n_word
    #print(node_attribute[node_idx_table[paper_id]])
    #print(" ")

# %%
# zero vectorの件数 (タイトル内のどの単語もword2vecのカバー範囲に含まれなかった件数)
sum(np.abs(node_attribute.sum(axis=1)) < 0.0000001)

# %%
from sklearn.cluster import MiniBatchKMeans
n_clusters = 10
kmeans_model = MiniBatchKMeans(n_clusters=n_clusters, batch_size=3000, random_state=42, max_iter=1000000, max_no_improvement=10000)
kmeans_model.fit(node_attribute)

# %%
kmeans_model.labels_

# %%
# 論文のラベルとしてcluster key を追加
for paper_id, meta in paper.items():
    paper[paper_id]["cluster"] = kmeans_model.labels_[node_idx_table[paper_id]]

# %%
# クラスタごとの論文を抽出して連結し文書化する。

def Isalnum(s):
    alnumReg = re.compile(r'^[a-zA-Z0-9]+$')
    return alnumReg.match(s) is not None

cluster_title_list = [[] for _ in range(n_clusters)]
for paper_id, meta in paper.items():
    cluster_title_list[meta['cluster']].append(meta['title'])

documents = []
for title_list in cluster_title_list:
    title_list = ' '.join(title_list)
    title_list = str.lower(title_list)
    notalnum = set()
    for s in set(title_list):
        if s != ' ' and not Isalnum(s):
            notalnum.add(s)
            #print(s) # 記号（文字や数値でないもの）
    for s in notalnum:
        title_list = title_list.replace(s, ' ')
    documents.append(title_list)

# %%
# TF-IDFを計算し、各クラスタごとの代表的な単語を上位数件表示する。

from gensim import corpora
from gensim import models

# gensim用に整形
texts = list(map(lambda x:x.split(),documents))

# 単語->id変換の辞書作成
dictionary = corpora.Dictionary(texts)
#print(dictionary.token2id)

# textsをcorpus化
corpus = list(map(dictionary.doc2bow,texts))
#print(corpus)

# tfidf modelの生成
test_model = models.TfidfModel(corpus)

# corpusへのモデル適用
corpus_tfidf = test_model[corpus]

texts_tfidf = []
for doc in corpus_tfidf:
    text_tfidf = []
    for word in doc:
        text_tfidf.append((dictionary[word[0]],word[1]))
    texts_tfidf.append(text_tfidf)

keyword_tfidf_cluster_list = []
for idx, text in enumerate(texts_tfidf):
    print('cluster:', idx)
    keyword_tfidf_cluster_list.append({})
    for keyword in sorted(text, key=lambda x:(x[1]), reverse=True)[:10]:
        print('   %.3f %s' %(keyword[1], keyword[0]))
        keyword_tfidf_cluster_list[idx][keyword[0]] = keyword[1]

# %%
keyword_tfidf_cluster_list

# %%
# !pip install cmake
# !pip install MulticoreTSNE

# %%
# 低次元に写像しクラスタを可視化（めちゃくちゃ遅い！！！）
from MulticoreTSNE import MulticoreTSNE as TSNE
import multiprocessing

print(multiprocessing.cpu_count())
t_sne = TSNE(n_jobs=multiprocessing.cpu_count()).fit_transform(node_attribute)
print('t_sne shape:', t_sne.shape)

# %%
aaa

# %%
# 年ごとのクラスタの割合をプロット (Deep MatchMaxが学習できるヒントがあるかもしれない)

# %%
aaa

# %%
# pandas 高速化 https://kunai-lab.hatenablog.jp/entry/2018/04/08/134924
df = pd.read_csv(outputDir + '/node_idx.csv')
df_node = df.node.values
df_ID = df.ID.values
node_idx_table2 = {}
for row in range(df.shape[0]):
    node_idx_table2[df_node[row]] = df_ID[row]
assert node_idx_table2 == node_idx_table, "いってこいになってない"

del df, df_node, df_ID, node_idx_table2, connected_component, sg, max_sg, paper_id_set, G, paper
gc.collect()

# %%
paper = {}
for file in ['dblp-ref-0.json', 'dblp-ref-1.json', 'dblp-ref-2.json', 'dblp-ref-3.json']:
#for file in ['dblp-ref-3.json']:
    with open(os.path.join(aminer_dir, file)) as f:
        for line in f:
            empty_flag = 0
            data = json.loads(line)
            paper_id = data.pop('id')
            if not paper_id in node_idx_table:
                continue
            if attribute_set & data.keys() != attribute_set:
                continue
            for attribute in attribute_set:
                if attribute == 'year' or attribute == 'n_citation':
                    continue
                if len(data[attribute]) == 0:
                    empty_flag = 1
            if empty_flag == 0:
                paper[paper_id] = data

len(paper)

# %%
dict_id2title = {}
for paper_id in paper.keys():
    dict_id2title[paper_id] = paper[paper_id]['title']
len(dict_id2title)

# %%
venue_dict = {}
for paper_id, meta in paper.items():
    if meta['venue'] in venue_dict.keys():
        venue_dict[meta['venue']] = venue_dict[meta['venue']] + 1
    else:
        venue_dict[meta['venue']] = 1

venue_list = []
for name, count in sorted(venue_dict.items(), key=lambda x: -x[1]):
    venue_list.append(name)

# %%
def GetListIndex(l, x, default=-1):
    if x in l:
        return l.index(x)
    else:
        return default

def Isalnum(s):
    alnumReg = re.compile(r'^[a-zA-Z0-9]+$')
    return alnumReg.match(s) is not None

venue_list = venue_list[:100]
title_groupby_venue_defaultdict = defaultdict(list)
for paper_id, meta in paper.items():
    if GetListIndex(venue_list, meta['venue']) != -1:
        title_groupby_venue_defaultdict[meta['venue']].append(meta['title'])

document_groupby_venue_dict = {}
for venue in venue_list:
    title_list = title_groupby_venue_defaultdict[venue]
    title_list = ' '.join(title_list)
    title_list = str.lower(title_list)
    notalnum = []
    for s in title_list:
        if s != ' ' and not Isalnum(s):
            notalnum.append(s)
            #print(s) # 記号（文字や数値でないもの）
    for s in notalnum:
        title_list = title_list.replace(s, ' ')
    document_groupby_venue_dict[venue] = title_list

# %%
rows = []
row = ['field', 0, 0, 100, 'VECTOR', True, False, False]
row.extend(sorted(venue_list))
row.extend(['other'])
rows.append(row)
columns = ['name', 'ID', 'range0', 'range1', 'type', 'primary', 'avg', 'cov']
classes = ['class' + str(i) for i in range(len(venue_list) + 1)]
columns.extend(classes)
df = pd.DataFrame(rows, columns=columns)
df.to_csv(outputDir + '/attribute_idx.csv', index=False, encoding='utf_8_sig')

# %%
from gensim import corpora
from gensim import models

documents = []
for venue in venue_list:
    documents.append(document_groupby_venue_dict[venue])
    
# gensim用に整形
texts = list(map(lambda x:x.split(),documents))

# 単語->id変換の辞書作成
dictionary = corpora.Dictionary(texts)
#print(dictionary.token2id)

# textsをcorpus化
corpus = list(map(dictionary.doc2bow,texts))
#print(corpus)

# tfidf modelの生成
test_model = models.TfidfModel(corpus)

# corpusへのモデル適用
corpus_tfidf = test_model[corpus]

texts_tfidf = []
for doc in corpus_tfidf:
    text_tfidf = []
    for word in doc:
        text_tfidf.append((dictionary[word[0]],word[1]))
    texts_tfidf.append(text_tfidf)

keyword_tfidf_venue_dict = {}
for idx, text in enumerate(texts_tfidf):
    print(venue_list[idx])
    keyword_tfidf_venue_dict[venue_list[idx]] = {}
    for keyword in sorted(text, key=lambda x:(x[1]), reverse=True)[:10]:
        print('   %.3f %s' %(keyword[1], keyword[0]))
        keyword_tfidf_venue_dict[venue_list[idx]][keyword[0]] = keyword[1]

# %%
title_venue_score = {}
for paper_id, meta in paper.items():
    title_venue_score[meta['title']] = {}
    word_list = meta['title'].split(' ')
    for venue, tfidf in keyword_tfidf_venue_dict.items():
        title_venue_score[meta['title']][venue] = 0
        for keyword, score in tfidf.items():
            for word in word_list:
                if keyword == str.lower(word):
                    title_venue_score[meta['title']][venue] = title_venue_score[meta['title']][venue] + score

# %%
title_venue_dict = {}
number = 0
for title, venue_score_dict in title_venue_score.items():
    number += 1
    if number < 100:
        print(title)
    for venue, score in sorted(venue_score_dict.items(), key=lambda x: x[1], reverse=True)[:5]:
        if number < 100:
            print('   %.3f %s' %(score, venue))
    #venue, score = sorted(venue_score_dict.items(), key=lambda x: x[1], reverse=True)[0]
    #if score == 0:
    #    title_venue_dict[title] = 'other'
    #    continue
    #title_venue_dict[title] = venue

# %%
title_venue_dict = {}
for title, venue_score_dict in title_venue_score.items():
    #title_venue_dict[title] = [0 for _ in range(len(venue_list))]
    title_venue_dict[title] = {}
    for venue, score in venue_score_dict.items():
        #title_venue_dict[title][GetListIndex(venue_list, venue)] = score
        title_venue_dict[title][venue] = score
    #score_sum = sum(title_venue_dict[title])
    score_sum = sum([score for venue, score in title_venue_dict[title].items()])
    if score_sum == 0:
        continue
    #for idx, score in enumerate(title_venue_dict[title]):
    #    title_venue_dict[title][idx] = score / score_sum
    for venue, score in title_venue_dict[title].items():
        title_venue_dict[title][venue] = score / score_sum

for title, score_list in title_venue_dict.items():
    if title == 'Evolutionary Chaos Controller Synthesis for Stabilizing Chaotic Hénon Maps.':
        print(title)
        for venue, score in score_list.items():
            print(venue, score)

# %%
years = set()
for paper_id, meta in paper.items():
    years.add(paper[paper_id]['year'])
years = list(years)
years.sort()
years

# %%
rows = []
for idx, year in enumerate(years):
    rows.append([year, idx])
df = pd.DataFrame(rows, columns=['TS', 'ID'])
df.to_csv(outputDir + '/ts_idx.csv', index=False, encoding='utf_8_sig')

# %%
# pandas 高速化 https://kunai-lab.hatenablog.jp/entry/2018/04/08/134924
df = pd.read_csv(outputDir + '/ts_idx.csv')
df_TS = df.TS.values
df_ID = df.ID.values
ts_idx_table = {}
for row in range(df.shape[0]):
    ts_idx_table[df_TS[row]] = df_ID[row]
ts_idx_table

# %%
exist_table = np.zeros((len(node_idx_table), len(ts_idx_table)))
for year in years:
    for paper_id, meta in paper.items():
        if year < meta['year']:
            exist_table[node_idx_table[paper_id]][ts_idx_table[year]] = 0
        else:
            exist_table[node_idx_table[paper_id]][ts_idx_table[year]] = 1

np.save(outputDir + '/exist_table', exist_table)

# %%
for year in years:
    node_attribute = np.zeros((len(node_idx_table), len(venue_list)+1))
    for paper_id, meta in paper.items():
        if year < meta['year']:
            continue
        field_vector = []
        for veneu, score in sorted(title_venue_dict[meta['title']].items(), key=lambda x:x[0]):
            field_vector.append(score)
        field_vector.append(0)
        if sum(field_vector) == 0:
            field_vector[100] = 1
        node_attribute[node_idx_table[paper_id]] = np.array(field_vector)
    np.save(outputDir + '/node_attribute' + str(ts_idx_table[year]), node_attribute)

# %%
for year in years:
    adjacency = lil_matrix((len(node_idx_table), len(node_idx_table)))
    for paper_id, meta in paper.items():
        if year < meta['year']:
            continue
        for reference_id in meta['references']:
            if not reference_id in node_idx_table.keys():
                continue
            adjacency[node_idx_table[paper_id], node_idx_table[reference_id]] = 1
    mmwrite(outputDir + '/adjacency' + str(ts_idx_table[year]), adjacency)

# %%
date2 = datetime.datetime.now()
print(date2)
